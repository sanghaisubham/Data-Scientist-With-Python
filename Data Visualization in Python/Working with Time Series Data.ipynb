# %% [markdown]
# ## Multiple Time Series on Common Axes
#
# Generating a single plot showing all the time series on common axes with a legend.

# %%
import pandas as pd
df=pd.read_csv('stocks.csv')

# %%
df
# Out:
#             Date        AAPL         IBM        CSCO        MSFT
# 0     2000-01-03  111.937502  116.000000  108.062500  116.562500
# 1     2000-01-04  102.500003  112.062500  102.000000  112.625000
# 2     2000-01-05  103.999997  116.000000  101.687500  113.812500
# 3     2000-01-06   94.999998  114.000000  100.000000  110.000000
# 4     2000-01-07   99.500001  113.500000  105.875000  111.437500
# 5     2000-01-10   97.750001  118.000000  109.812500  112.250000
# 6     2000-01-11   92.750000  119.000000  106.500000  109.375000
# 7     2000-01-12   87.187503  119.500000  103.812500  105.812500
# 8     2000-01-13   96.749998  118.250000  106.187500  107.812500
# 9     2000-01-14  100.437499  119.625000  107.562500  112.250000
# 10    2000-01-18  103.937499  115.750000  112.000000  115.312500
# 11    2000-01-19  106.562499  119.500000  112.312500  107.000000
# 12    2000-01-20  113.499994  119.000000  112.375000  106.000000
# ...

# %%
# Import matplotlib.pyplot
import matplotlib.pyplot as  plt

# Plot the aapl time series in blue
plt.plot(df['AAPL'],color='blue', label='AAPL')

# Plot the ibm time series in green
plt.plot(df['IBM'],color='green',label='IBM')

# Plot the csco time series in red
plt.plot(df['CSCO'],color='red',label='CSCO')

# Plot the msft time series in magenta
plt.plot(df['MSFT'],color='magenta',label='MSFT')

# Add a legend in the top left corner of the plot
plt.legend(loc='upper left')

# Specify the orientation of the xticks
plt.xticks(rotation=60)

# Display the plot
plt.show()

# %% [markdown]
# We can easily slice subsets corresponding to different time intervals from a time series. In particular, we can use strings like '2001:2005', '2011-03:2011-12', or '2010-04-19:2010-04-30' to extract data from time intervals of length 5 years, 10 months, or 12 days respectively.

# %%
df.index=df['Date']
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
aapl=df['AAPL']
# Plot the series in the top subplot in blue
plt.subplot(2,1,1)
plt.xticks(rotation=45)
plt.title('AAPL: 2001 to 2011')
plt.plot(aapl, color='blue')

# Slice aapl from '2007' to '2008' inclusive: view
view = aapl['2007':'2008']

# Plot the sliced data in the bottom subplot in black
plt.subplot(2,1,2)
plt.xticks(rotation=45)
plt.title('AAPL: 2007 to 2008')
plt.plot(view,color=black)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-61799eed24cb> in <module>()
#       7
#       8 # Slice aapl from '2007' to '2008' inclusive: view
# ----> 9 view = aapl['2007':'2008']
#      10
#      11 # Plot the sliced data in the bottom subplot in black
#
# C:\Users\Subham\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     640             key = check_bool_indexer(self.index, key)
#     641
# --> 642         return self._get_with(key)
#     643
#     644     def _get_with(self, key):
#
# C:\Users\Subham\Anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     645         # other: fancy integer or otherwise
#     646         if isinstance(key, slice):
# --> 647             indexer = self.index._convert_slice_indexer(key, kind='getitem')
#     648             return self._get_values(indexer)
# ...

# %%
# Slice aapl from Nov. 2007 to Apr. 2008 inclusive: view
view = aapl['2007-11':'2008-04']

# Plot the sliced series in the top subplot in red
plt.subplot(2,1,1)
plt.plot(view,color='red')
plt.title('AAPL: Nov. 2007 to Apr. 2008')
plt.xticks(rotation=45)

# Reassign the series by slicing the month January 2008
view = aapl['2008-01']

# Plot the sliced series in the bottom subplot in green
plt.subplot(2,1,2)
plt.plot(view,color='green')

plt.title('AAPL: Jan. 2008')
plt.xticks(rotation=45)

# Improve spacing and display the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-bc1606532adf> in <module>()
#       1 # Slice aapl from Nov. 2007 to Apr. 2008 inclusive: view
# ----> 2 view = aapl['2007-11':'2008-04']
#       3
#       4 # Plot the sliced series in the top subplot in red
#       5 plt.subplot(2,1,1)
#
# C:\Users\Subham\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     640             key = check_bool_indexer(self.index, key)
#     641
# --> 642         return self._get_with(key)
#     643
#     644     def _get_with(self, key):
#
# C:\Users\Subham\Anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     645         # other: fancy integer or otherwise
#     646         if isinstance(key, slice):
# --> 647             indexer = self.index._convert_slice_indexer(key, kind='getitem')
# ...

# %% [markdown]
# ## Plotting an inset view
#
# Rather than comparing plots with subplots or overlayed plots, we can generate an inset view directly using plt.axes(). We'll reproduce two of the time series plots from the preceding two exercises. Our figure will contain an inset plot to highlight the dramatic changes in AAPL stock price between November 2007 and April 2008 (as compared to the 11 years from 2001 to 2011).

# %%
# Slice aapl from Nov. 2007 to Apr. 2008 inclusive: view
view = aapl['2007-11':'2008-04']

# Plot the entire series 
plt.plot(aapl)
plt.xticks(rotation=45)
plt.title('AAPL: 2001-2011')

# Specify the axes
plt.axes([0.25, 0.5, 0.35, 0.35])#set of axes with lower left corner (0.25, 0.5), width 0.35, and height 0.35

# Plot the sliced series in red using the current axes
plt.plot(view, color='red')
plt.xticks(rotation=45)
plt.title('2007/11-2008/04')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-79fbffdb7d72> in <module>()
#       1 # Slice aapl from Nov. 2007 to Apr. 2008 inclusive: view
# ----> 2 view = aapl['2007-11':'2008-04']
#       3
#       4 # Plot the entire series
#       5 plt.plot(aapl)
#
# C:\Users\Subham\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     640             key = check_bool_indexer(self.index, key)
#     641
# --> 642         return self._get_with(key)
#     643
#     644     def _get_with(self, key):
#
# C:\Users\Subham\Anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     645         # other: fancy integer or otherwise
#     646         if isinstance(key, slice):
# --> 647             indexer = self.index._convert_slice_indexer(key, kind='getitem')
#     648             return self._get_values(indexer)
# ...

# %% [markdown]
# ## Plotting moving averages
#
# Now we will plot pre-computed moving averages of AAPL stock prices in distinct subplots.
#
#     The time series aapl is overlayed in black in each subplot for comparison.The time series mean_30, mean_75, mean_125, and mean_250 have been computed (containing the windowed averages of the series aapl computed over windows of width 30 days, 75 days, 125 days, and 250 days respectively).

# %%
# Plot the 30-day moving average in the top left subplot in green
plt.subplot(2,2,1)
plt.plot(mean_30,'green')
plt.plot(aapl, 'k-.')
plt.xticks(rotation=60)
plt.title('30d averages')

# Plot the 75-day moving average in the top right subplot in red
plt.subplot(2,2,2)
plt.plot(mean_75, 'red')
plt.plot(aapl, 'k-.')
plt.xticks(rotation=60)
plt.title('75d averages')

# Plot the 125-day moving average in the bottom left subplot in magenta
plt.subplot(2, 2, 3)
plt.plot(mean_125, 'magenta')
plt.plot(aapl, 'k-.')
plt.xticks(rotation=60)
plt.title('125d averages')

# Plot the 250-day moving average in the bottom right subplot in cyan
plt.subplot(2,2,4)
plt.plot(mean_250, 'cyan')
plt.plot(aapl, 'k-.')
plt.xticks(rotation=60)
plt.title('250d averages')

# Display the plot
plt.show()

# %% [markdown]
# ## Plotting moving standard deviations

# %%
# Plot std_30 in red
plt.plot(std_30,'red', label='30d')

# Plot std_75 in cyan
plt.plot(std_75,'cyan',label='75d')

# Plot std_125 in green
plt.plot(std_125,'green',label='125d')

# Plot std_250 in magenta
plt.plot(std_250,'magenta',label='250d')

# Add a legend to the upper left
plt.legend(loc='upper left')

# Add a title
plt.title('Moving standard deviations')

# Display the plot
plt.show()
