# %% [markdown]
# # Processing

# %% [markdown]
# We'll use alpha-numeric sequences, and only alpha-numeric sequences, as tokens. Alpha-numeric tokens contain only letters a-z and numbers 0-9 (no other characters). In other words, we'll tokenize on punctuation to generate n-gram statistics.

# %%
import pandas as pd
df=pd.read_csv('Training_Data.csv',index_col=0)
LABELS=['Function',
 'Use',
 'Sharing',
 'Reporting',
 'Student_Type',
 'Position_Type',
 'Object_Type',
 'Pre_K',
 'Operating_Status']
# Define the lambda function: categorize_label
categorize_label = lambda x: x.astype('category')

# Convert df[LABELS] to a categorical type
df[LABELS] = df[LABELS].apply(categorize_label,axis=0)
print(df.dtypes)
# Out:
# Function                  category
# Use                       category
# Sharing                   category
# Reporting                 category
# Student_Type              category
# Position_Type             category
# Object_Type               category
# Pre_K                     category
# Operating_Status          category
# Object_Description          object
# Text_2                      object
# SubFund_Description         object
# Job_Title_Description       object
# Text_3                      object
# Text_4                      object
# Sub_Object_Description      object
# Location_Description        object
# FTE                        float64
# Function_Description        object
# Facility_or_Department      object
# Position_Extra              object
# Total                      float64
# Program_Description         object
# Fund_Description            object
# Text_1                      object
# dtype: object

# %%
import numpy as np
import pandas as pd

def multilabel_sample(y, size=1000, min_count=5, seed=None):
    """ Takes a matrix of binary labels `y` and returns
        the indices for a sample of size `size` if
        `size` > 1 or `size` * len(y) if size =< 1.
        The sample is guaranteed to have > `min_count` of
        each label.
    """
    try:
        if (np.unique(y).astype(int) != np.array([0, 1])).all():
            raise ValueError()
    except (TypeError, ValueError):
        raise ValueError('multilabel_sample only works with binary indicator matrices')

    if (y.sum(axis=0) < min_count).any():
        raise ValueError('Some classes do not have enough examples. Change min_count if necessary.')

    if size <= 1:
        size = np.floor(y.shape[0] * size)

    if y.shape[1] * min_count > size:
        msg = "Size less than number of columns * min_count, returning {} items instead of {}."
        warn(msg.format(y.shape[1] * min_count, size))
        size = y.shape[1] * min_count

    rng = np.random.RandomState(seed if seed is not None else np.random.randint(1))

    if isinstance(y, pd.DataFrame):
        choices = y.index
        y = y.values
    else:
        choices = np.arange(y.shape[0])

    sample_idxs = np.array([], dtype=choices.dtype)

    # first, guarantee > min_count of each label
    for j in range(y.shape[1]):
        label_choices = choices[y[:, j] == 1]
        label_idxs_sampled = rng.choice(label_choices, size=min_count, replace=False)
        sample_idxs = np.concatenate([label_idxs_sampled, sample_idxs])

    sample_idxs = np.unique(sample_idxs)

    # now that we have at least min_count of each, we can just random sample
    sample_count = int(size - sample_idxs.shape[0])

    # get sample_count indices from remaining choices
    remaining_choices = np.setdiff1d(choices, sample_idxs)
    remaining_sampled = rng.choice(remaining_choices,
                                   size=sample_count,
                                   replace=False)

    return np.concatenate([sample_idxs, remaining_sampled])


def multilabel_sample_dataframe(df, labels, size, min_count=5, seed=None):
    """ Takes a dataframe `df` and returns a sample of size `size` where all
        classes in the binary matrix `labels` are represented at
        least `min_count` times.
    """
    idxs = multilabel_sample(labels, size=size, min_count=min_count, seed=seed)
    return df.loc[idxs]


def multilabel_train_test_split(X, Y, size, min_count=5, seed=None):
    """ Takes a features matrix `X` and a label matrix `Y` and
        returns (X_train, X_test, Y_train, Y_test) where all
        classes in Y are represented at least `min_count` times.
    """
    index = Y.index if isinstance(Y, pd.DataFrame) else np.arange(Y.shape[0])

    test_set_idxs = multilabel_sample(Y, size=size, min_count=min_count, seed=seed)
    train_set_idxs = np.setdiff1d(index, test_set_idxs)

    test_set_mask = index.isin(test_set_idxs)
    train_set_mask = ~test_set_mask

    return (X[train_set_mask], X[test_set_mask], Y[train_set_mask], Y[test_set_mask])

# %%
from sklearn.preprocessing import FunctionTransformer

# Get the dummy encoding of the labels
dummy_labels = pd.get_dummies(df[LABELS])

# Get the columns that are features in the original df
NON_LABELS = [c for c in df.columns if c not in LABELS]

# Split into training and test sets
X_train, X_test, y_train, y_test = multilabel_train_test_split(df[NON_LABELS],
                                                               dummy_labels,
                                                               0.2, 
                                                               seed=123)

# %%
# Define combine_text_columns()
NUMERIC_COLUMNS=['FTE','Total']
def combine_text_columns(data_frame, to_drop=NUMERIC_COLUMNS + LABELS):
    """ converts all text in each row of data_frame to single vector by converting all NAN's into " " and joining on spaces"""
    
    print("\n\nThe Initial To_Drop contains")
    print("---------------------------------\n\n")
    print(to_drop)
    print('\n')
    print("\n\nThe Initial Columns of the DataFrame are:")
    print("----------------------------------------\n\n")
    print(data_frame.columns.tolist())
    print('\n')
    # Drop non-text columns that are in the df
    to_drop = set(to_drop) & set(data_frame.columns.tolist())
    print("\n\nThe Final To_Drop Contains : ")
    print("---------------------------------\n\n")
    print(to_drop)
    
    #to_drop contains the columns to be dropped(NON-TEXT Columns)
    text_data =data_frame.drop(to_drop,axis=1)
    print("\n\n THE SHAPE OF TEXT DATA")
    print("--------------------\n\n")
    print(text_data.shape)
    print("\n\nTHE TEXT DATA IS:")
    print("--------------------\n\n")
    print(text_data)
    
    
    # Replace nans with blanks
    text_data.fillna("",inplace=True)
    print("\n\n THE SHAPE OF NEW TEXT DATA")
    print("--------------------\n\n")
    print(text_data.shape)
    print("\n\nNow the New TEXT DATA IS:")
    print("-----------------------------\n\n\n")
    print(text_data)
    
    
    # Join all text items in a row that have a space in between
    return text_data.apply(lambda x: " ".join(x), axis=1)

# %%
# Import the CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# Create the text vector
text_vector = combine_text_columns(X_train)
print("\n\n THE SHAPE OF TEXT VECTOR(Outside Function)")
print("--------------------\n\n")
print(text_vector.shape)
print("\n\nTHE TEXT VECTOR IS(Outside Function) :: ")
print("--------------------------------------\n\n")
print(text_vector)


# Create the token pattern: TOKENS_ALPHANUMERIC
TOKENS_ALPHANUMERIC = '[A-Za-z0-9]+(?=\\s+)'

# Instantiate the CountVectorizer: text_features
text_features =CountVectorizer(token_pattern=TOKENS_ALPHANUMERIC)

# Fit text_features to the text vector
text_features.fit(text_vector)

# Print the first 10 tokens
print(len(text_features.get_feature_names()))
for word in text_features.get_feature_names():
    print(word)
# Out:
# The Initial To_Drop contains
# ---------------------------------
#
#
# ['FTE', 'Total', 'Function', 'Use', 'Sharing', 'Reporting', 'Student_Type', 'Position_Type', 'Object_Type', 'Pre_K', 'Operating_Status']
#
#
#
#
# The Initial Columns of the DataFrame are:
# ----------------------------------------
#
#
# ['Object_Description', 'Text_2', 'SubFund_Description', 'Job_Title_Description', 'Text_3', 'Text_4', 'Sub_Object_Description', 'Location_Description', 'FTE', 'Function_Description', 'Facility_or_Department', 'Position_Extra', 'Total', 'Program_Description', 'Fund_Description', 'Text_1']
#
#
#
#
# The Final To_Drop Contains :
# ---------------------------------
#
#
# {'Total', 'FTE'}
#
#
#  THE SHAPE OF TEXT DATA
# --------------------
#
#
# (320222, 14)
#
#
# THE TEXT DATA IS:
# --------------------
#
#
#                                        Object_Description  \
# 134338                                                NaN
# 326408                       Personal Services - Teachers
# 364634                                  EMPLOYEE BENEFITS
# 47683                        TEACHER COVERAGE FOR TEACHER
# 229958                                    CONTRA BENEFITS
# 417668                                        EDUCATIONAL
# 126378                                  EMPLOYEE BENEFITS
# 85262                                   EMPLOYEE BENEFITS
# 304569                                        EQUIPMENT *
# 84272                        Personal Services - Teachers
# 64760                                           Regular *
# 21870                      OTHER PERSONAL SERVICES
# 169454                     SUPPLIES
# 169914                                          Regular *
# 189701                                        ELECTRICITY
# 43727               Non-Certificated Travel Reimbursement
# 5614                                   Purchased Services
# 307038                                          Regular *
# 27645                      BONUSES
# 126388  Personal Services - Substitute Teachers Certified
# 14962                        Personal Services - Teachers
# 84040                                         EQUIPMENT *
# 61639                                   EMPLOYEE BENEFITS
# 266302                                  EMPLOYEE BENEFITS
# 225768      Extra Duty Pay/Overtime For Support Personnel
# 267322                                    CONTRA BENEFITS
# 308098      Extra Duty Pay/Overtime For Support Personnel
# 227367                                 Purchased Services
# 329096                      SALARIES OF REGULAR EMPLOYEES
# 282308                     OTHER SUPPORT PERSONNEL
# ...                                                   ...
# 209265                                                NaN
# 333748                                          Regular *
# 292626      Extra Duty Pay/Overtime For Support Personnel
# 343458                     SALARIES OF PART TIME EMPLOYEE
# 128261                      SALARIES OF REGULAR EMPLOYEES
# 186318                      SALARIES OF REGULAR EMPLOYEES
# 210652  Personal Services - Substitute Teachers Non-Ce...
# 340354                                  EMPLOYEE BENEFITS
# 435205                       EMPLOYER PD MED CONTRIBUTION
# 174827                     SALARIES OF PART TIME EMPLOYEE
# 277504                                    CONTRA BENEFITS
# 248062             Travel And Subsistence - Employee Only
# 70455                      CLASSROOM TEACHER
# 203453                     IN-COUNTY TRAVEL
# 58170   Personal Services - Substitute Teachers Certified
# 68311                      ADDITIONAL/EXTRA DUTY PAY/STIP
# 225892                      SALARIES OF REGULAR EMPLOYEES
# 446383                Other Pupil Transportation Services
# 155111      Extra Duty Pay/Overtime For Support Personnel
# 278248                                           SUPPLIES
# 397424                     ADDITIONAL/EXTRA DUTY PAY/STIP
# 375092  Personal Services - Substitute Teachers Certified
# 220181            Salaries Or Wages For Support Personnel
# 307423                            Other Awards and Prizes
# 46691                      ADDITIONAL/EXTRA DUTY PAY/STIP
# 109283                     WORKSHOP PARTICIPANT
# 102430                     SALARIES OF PART TIME EMPLOYEE
# 413949                                                NaN
# 433672                                  EMPLOYEE BENEFITS
# 415831    Salaries And Wages For Substitute Professionals
#
#                                Text_2  \
# 134338                            NaN
# 326408                            NaN
# 364634                   TEACHER SUBS
# 47683                    TEACHER SUBS
# 229958                            NaN
# 417668  SPECIAL EDUCATION INSTRUCTION
# 126378                            NaN
# 85262                    TEACHER SUBS
# 304569                            NaN
# 84272                             NaN
# 64760                             NaN
# 21870                             NaN
# 169454                            NaN
# 169914                       ADM/PROF
# 189701         OPERATIONS - UTILITIES
# 43727                             NaN
# 5614                              NaN
# 307038                        TEACHER
# 27645                             NaN
# 126388                            NaN
# 14962                             NaN
# 84040                             NaN
# 61639                             NaN
# 266302                            NaN
# 225768                            NaN
# 267322                            NaN
# 308098                            NaN
# 227367                            NaN
# 329096                  FOOD SERVICES
# 282308                            NaN
# ...                               ...
# 209265                            NaN
# 333748                     TEACHERSUP
# 292626                            NaN
# 343458                   TEACHER SUBS
# 128261            SEVERE DISABILITIES
# 186318                            NaN
# 210652                            NaN
# 340354                            NaN
# 435205                            NaN
# 174827                            NaN
# 277504                            NaN
# 248062                            NaN
# 70455                             NaN
# 203453                            NaN
# 58170                             NaN
# 68311                    MATH/SCIENCE
# 225892                            NaN
# 446383                            NaN
# 155111                            NaN
# 278248                            NaN
# 397424                            NaN
# 375092                            NaN
# 220181                            NaN
# 307423                            NaN
# 46691                    MATH/SCIENCE
# 109283                            NaN
# 102430                            NaN
# 413949                            NaN
# 433672  EDUCATIONAL RESOURCE SERVICES
# 415831                            NaN
#
#                                 SubFund_Description  \
# 134338                                          NaN
# 326408                                          NaN
# 364634                                 GENERAL FUND
# 47683                                  GENERAL FUND
# 229958                                 GENERAL FUND
# 417668                                        LOCAL
# 126378                                 GENERAL FUND
# 85262                                  GENERAL FUND
# 304569            Support Services - Administration
# 84272                                           NaN
# 64760                           Special Instruction
# 21870                                           NaN
# 169454                                          NaN
# 169914  Operation and Maintenance of Plant Services
# 189701                                 GENERAL FUND
# 43727        Support Services - Instructional Staff
# 5614                       Support Services--Pupils
# 307038                          Special Instruction
# 27645                                           NaN
# 126388                                          NaN
# 14962                                           NaN
# 84040        Support Services - Instructional Staff
# 61639                                  GENERAL FUND
# 266302                                 GENERAL FUND
# 225768                                   Operations
# 267322                                 GENERAL FUND
# 308098                                   Operations
# 227367                           Community Services
# 329096                            FOOD SERVICE FUND
# 282308                                          NaN
# ...                                             ...
# 209265                                          NaN
# 333748                     Support Services--Pupils
# 292626                                   Operations
# 343458                                 GENERAL FUND
# 128261                                 GENERAL FUND
# 186318                                 GENERAL FUND
# 210652                                          NaN
# 340354                      FEDERAL GDPG FUND - FY
# 435205                    STATE AND LOCAL GDPG FUND
# 174827                      FEDERAL GDPG FUND - FY
# 277504                                 GENERAL FUND
# 248062                                          NaN
# 70455                                           NaN
# 203453                                          NaN
# 58170                                           NaN
# 68311                       FEDERAL GDPG FUND - FY
# 225892                                 GENERAL FUND
# 446383       Support Services - Instructional Staff
# 155111                                   Operations
# 278248                      PRIMARY GRADES PROGRAM
# 397424                                         BOND
# 375092                                          NaN
# 220181                              Child Nutrition
# 307423       Support Services - Instructional Staff
# 46691                       FEDERAL GDPG FUND - FY
# 109283                                          NaN
# 102430                      FEDERAL GDPG FUND - FY
# 413949                                          NaN
# 433672                                LEVY OVERRIDE
# 415831     "Title  Part A Improving Basic Programs"
#
#                          Job_Title_Description       Text_3  \
# 134338                     Teacher-Elementary           NaN
# 326408                         TCHER 2ND GRADE          NaN
# 364634                Teacher, Short Term Sub       Regular
# 47683               Teacher, Secondary (High)   Alternative
# 229958                 Custodian - PT -  Jobs           n/a
# 417668                                     NaN          NaN
# 126378              Sub Manager, Food Service           n/a
# 85262             Teacher,Retrd Shrt Term Sub       Regular
# 304569                                     NaN          NaN
# 84272   TCHER P E (ELEM POSITION CONTROL POOL)          NaN
# 64760                                      NaN          NaN
# 21870           SUB TEACHER ALL                         NaN
# 169454          TEACHER, TITLE I-ELEM                   NaN
# 169914              ADMIN LIEUTENANT COMM SERV          NaN
# 189701                                 (blank)      Regular
# 43727                                      NaN          NaN
# 5614                                       NaN          NaN
# 307038                     TCHR, SCNDY ENGLISH          NaN
# 27645           ESE CLERICAL ASSISTANT II               NaN
# 126388                                     NaN          NaN
# 14962                TCHER ENGLISH (SECONDARY)          NaN
# 84040                                      NaN          NaN
# 61639                 Teacher, Short Term Sub       Regular
# 266302                    Teacher, Elementary       Regular
# 225768          TRANSPORTATION,BUS DRIVERS,REG          NaN
# 267322             Teacher,Spec Ed Center Prg           n/a
# 308098          TRANSPORTATION,BUS DRIVERS,REG          NaN
# 227367                                     NaN          NaN
# 329096               Manager, Food Service IV           n/a
# 282308          FOOD SERVICE ASSISTANT                  NaN
# ...                                        ...          ...
# 209265                   Teacher-Middle School          NaN
# 333748                            PSYCHOLOGIST          NaN
# 292626           CLERICAL, BLDG.& CONSTRUCTION          NaN
# 343458                 Teacher, Super Sub D/D           n/a
# 128261             Teacher,Spec Ed Center Prg       Regular
# 186318                    Teacher, Elementary       Regular
# 210652                                     NaN          NaN
# 340354                 ELA General Assignment       Regular
# 435205                    Teacher, Elementary       Regular
# 174827                 ELA General Assignment       Regular
# 277504                    Teacher, Elementary           n/a
# 248062                                     NaN          NaN
# 70455           TEACHER, SOC STUDIES-MIDDLE             NaN
# 203453                                     NaN          NaN
# 58170                                      NaN          NaN
# 68311                     Teacher, Elementary           n/a
# 225892                    Teacher, Elementary       Regular
# 446383                                     NaN          NaN
# 155111          TRANSPORTATION, SUBSTITUTE,REG          NaN
# 278248                                     NaN          NaN
# 397424                 Secondary Spec Ed Para    Turnaround
# 375092                                     NaN          NaN
# 220181          CAFETERIA EMPLOYEE, FOOD SERV.          NaN
# 307423                                     NaN          NaN
# 46691                     Teacher, Elementary           n/a
# 109283          CURRICULUM RESOURCE TEACHER             NaN
# 102430            Teacher,Retrd Shrt Term Sub       Regular
# 413949                          School Liaison          NaN
# 433672                  Library Technician II           n/a
# 415831                 TEACHER SUBSTITUTE POOL          NaN
#
#                                     Text_4  \
# 134338                                 NaN
# 326408                 Regular Instruction
# 364634                                 NaN
# 47683                                  NaN
# 229958                                 NaN
# 417668                                 NaN
# 126378                                 NaN
# 85262                                  NaN
# 304569                                 NaN
# 84272                  Regular Instruction
# 64760                                  NaN
# 21870                                  NaN
# 169454                                 NaN
# 169914                                 NaN
# 189701                                 NaN
# 43727                                  NaN
# 5614                                   NaN
# 307038                                 NaN
# 27645                                  NaN
# 126388                 Regular Instruction
# 14962                           SIG - ARRA
# 84040                                  NaN
# 61639                                  NaN
# 266302                                 NaN
# 225768        Transportation - Bus Drivers
# 267322                                 NaN
# 308098        Transportation - Bus Drivers
# 227367                                 NaN
# 329096                                 NaN
# 282308                                 NaN
# ...                                    ...
# 209265                                 NaN
# 333748                                 NaN
# 292626                                 NaN
# 343458                                 NaN
# 128261                                 NaN
# 186318                                 NaN
# 210652                       IDEA Part B
# 340354                                 NaN
# 435205                                 NaN
# 174827                                 NaN
# 277504                                 NaN
# 248062                                 NaN
# 70455                                  NaN
# 203453                                 NaN
# 58170                      State TIF Grant
# 68311                                  NaN
# 225892                                 NaN
# 446383                                 NaN
# 155111        transportation - Second Runs
# 278248                                 NaN
# 397424                                 NaN
# 375092                 Regular Instruction
# 220181                       Undistributed
# 307423                                 NaN
# 46691                                  NaN
# 109283                                 NaN
# 102430                                 NaN
# 413949                                 NaN
# 433672                                 NaN
# 415831  Multilingual Dist Prof Development
#
#                                Sub_Object_Description  \
# 134338                                            NaN
# 326408                                            NaN
# 364634                                            NaN
# 47683                                             NaN
# 229958                                            NaN
# 417668                                            NaN
# 126378                                            NaN
# 85262                                             NaN
# 304569                                    Equipment *
# 84272                                             NaN
# 64760       Certificated Employees Salaries And Wages
# 21870                                             NaN
# 169454                                            NaN
# 169914                                            NaN
# 189701                                            NaN
# 43727                Travel Mileage/Meeting Expense *
# 5614                               Purchased Services
# 307038      Certificated Employees Salaries And Wages
# 27645                                             NaN
# 126388                                            NaN
# 14962                                             NaN
# 84040                                     Equipment *
# 61639                                             NaN
# 266302                                            NaN
# 225768  Extra Duty Pay/Overtime For Support Personnel
# 267322                                            NaN
# 308098  Extra Duty Pay/Overtime For Support Personnel
# 227367                             Purchased Services
# 329096                                            NaN
# 282308                                            NaN
# ...                                               ...
# 209265                                            NaN
# 333748      Certificated Employees Salaries And Wages
# 292626  Extra Duty Pay/Overtime For Support Personnel
# 343458                                            NaN
# 128261                                            NaN
# 186318                                            NaN
# 210652                                            NaN
# 340354                                            NaN
# 435205                                            NaN
# 174827                                            NaN
# 277504                                            NaN
# 248062         Travel And Subsistence - Employee Only
# 70455                                             NaN
# 203453                                            NaN
# 58170                                             NaN
# 68311                                             NaN
# 225892                                            NaN
# 446383                         Pupil Transportation *
# 155111  Extra Duty Pay/Overtime For Support Personnel
# 278248                                            NaN
# 397424                                            NaN
# 375092                                            NaN
# 220181        Salaries Or Wages For Support Personnel
# 307423                            Awards And Prizes *
# 46691                                             NaN
# 109283                                            NaN
# 102430                                            NaN
# 413949                                            NaN
# 433672                                            NaN
# 415831     Inservice Substitute Teachers Grant Funded
#
#                   Location_Description  \
# 134338                             NaN
# 326408                             NaN
# 364634                             NaN
# 47683                              NaN
# 229958                             NaN
# 417668                             NaN
# 126378  DISTRICT WIDE ORGANIZATION UNI
# 85262                              NaN
# 304569                             NaN
# 84272                              NaN
# 64760                              NaN
# 21870                          CHARTER
# 169454                         School
# 169914    SAFETY AND SECURITY DIVISION
# 189701                             NaN
# 43727                              NaN
# 5614                               NaN
# 307038      SR OTH CERTIFICATED PERSON
# 27645                          CHARTER
# 126388                             NaN
# 14962                              NaN
# 84040                              NaN
# 61639                              NaN
# 266302                             NaN
# 225768                   Undistributed
# 267322                             NaN
# 308098                   Undistributed
# 227367                             NaN
# 329096                             NaN
# 282308                         School
# ...                                ...
# 209265                             NaN
# 333748      PSYCHOLOGICAL SERVICES OFF
# 292626                     Unallocated
# 343458       ALL SCHOOLS-UNDISTRIBUTED
# 128261                             NaN
# 186318                             NaN
# 210652                             NaN
# 340354                             NaN
# 435205                             NaN
# 174827                             NaN
# 277504                             NaN
# 248062                         School
# 70455                          School
# 203453                         School
# 58170                              NaN
# 68311                   MATH / SCIENCE
# 225892                             NaN
# 446383                             NaN
# 155111                     Unallocated
# 278248                             NaN
# 397424                             NaN
# 375092                             NaN
# 220181                         School
# 307423                             NaN
# 46691                   MATH / SCIENCE
# 109283  STAFF DEV AND INSTR MEDIA
# 102430                             NaN
# 413949                             NaN
# 433672            ED RESOURCE SERVICES
# 415831                         School
#
#                                      Function_Description  \
# 134338                                                NaN
# 326408                                                NaN
# 364634                            UNALLOC BUDGETS/SCHOOLS
# 47683                                         NON-PROJECT
# 229958                                        NON-PROJECT
# 417668                                                NaN
# 126378                                        NON-PROJECT
# 85262                             UNALLOC BUDGETS/SCHOOLS
# 304569  State and Federal Projects Coordination Services*
# 84272                                                 NaN
# 64760                               Disadvantaged Youth *
# 21870                      BASIC (FEFP K-12)
# 169454                     BASIC (FEFP K-12)
# 169914                                  Security Services
# 189701                                        NON-PROJECT
# 43727   Instruction And Curriculum Development Services *
# 5614             Direction Of Support Services - Pupils *
# 307038                              Disadvantaged Youth *
# 27645                      GUIDANCE SERVICES
# 126388                                                NaN
# 14962                                                 NaN
# 84040   Instruction And Curriculum Development Services *
# 61639                                        CORE MATTERS
# 266302                       ELA E-TEACHING SHELTERED ENG
# 225768                                     Transportation
# 267322                                        NON-PROJECT
# 308098                                     Transportation
# 227367                         Other Community Services *
# 329096                                        NON-PROJECT
# 282308                     FOOD SERVICE
# ...                                                   ...
# 209265                                                NaN
# 333748                           Psychological Services *
# 292626            Facilities Acquisition And Construction
# 343458                            UNALLOC BUDGETS/SCHOOLS
# 128261                         SPECIAL ED. - SEVERE NEEDS
# 186318                      ELA S - TEACHING SPANISH ONLY
# 210652                                                NaN
# 340354                                     TITLE III  ELA
# 435205                        READ TO ACHIEVE ROUND THREE
# 174827                                            TITLE I
# 277504                                        NON-PROJECT
# 248062  Curriculum Development And Instructional Staff...
# 70455                      BASIC (FEFP K-12)
# 203453                     STAFF SERVICES
# 58170                                                 NaN
# 68311                      TITLE II-PART A-TEACHER QUALIT
# 225892                       ELA E-TEACHING SHELTERED ENG
# 446383  Instruction And Curriculum Development Services *
# 155111                                     Transportation
# 278248                                        INSTRUCTION
# 397424                                            NS  GOB
# 375092                                                NaN
# 220181          Food Services (Child Nutrition Fund Only)
# 307423       Other Improvements Of Instruction Services *
# 46691                      TITLE II-PART A-TEACHER QUALIT
# 109283                     INST STAFF TRAINING SVCS
# 102430                                         TITLE II,D
# 413949                                                NaN
# 433672                                        NON-PROJECT
# 415831                                        Instruction
#
#                             Facility_or_Department  \
# 134338                                         NaN
# 326408                                         NaN
# 364634                                         NaN
# 47683                                          NaN
# 229958                                         NaN
# 417668                                         NaN
# 126378                                         NaN
# 85262                                          NaN
# 304569                                         NaN
# 84272                       POSITION CONTROL POOLS
# 64760                                          NaN
# 21870                                          NaN
# 169454                                         NaN
# 169914                                         NaN
# 189701                                         NaN
# 43727                                          NaN
# 5614                                           NaN
# 307038                                         NaN
# 27645                                          NaN
# 126388                                         NaN
# 14962                                          NaN
# 84040                                          NaN
# 61639                                          NaN
# 266302                                         NaN
# 225768                   Transportation Department
# 267322                                         NaN
# 308098                   Transportation Department
# 227367                                         NaN
# 329096                                         NaN
# 282308                                         NaN
# ...                                            ...
# 209265                                         NaN
# 333748                                         NaN
# 292626  New Construction Department Administration
# 343458                                         NaN
# 128261                                         NaN
# 186318                                         NaN
# 210652                              TEACHER SUPPLY
# 340354                                         NaN
# 435205                                         NaN
# 174827                                         NaN
# 277504                                         NaN
# 248062                                  Vocational
# 70455                                          NaN
# 203453                                         NaN
# 58170                                          NaN
# 68311                                          NaN
# 225892                                         NaN
# 446383                                         NaN
# 155111                   Transportation Department
# 278248                                         NaN
# 397424                                         NaN
# 375092                                         NaN
# 220181                             Child Nutrition
# 307423                                         NaN
# 46691                                          NaN
# 109283                                         NaN
# 102430                                         NaN
# 413949                                         NaN
# 433672                                         NaN
# 415831                  Instruction And Curriculum
#
#                        Position_Extra             Program_Description  \
# 134338                  KINDERGARTEN                     KINDERGARTEN
# 326408                        TEACHER           Instruction - Regular
# 364634     PROFESSIONAL-INSTRUCTIONAL  GENERAL MIDDLE/JUNIOR HIGH SCH
# 47683      PROFESSIONAL-INSTRUCTIONAL   GENERAL HIGH SCHOOL EDUCATION
# 229958                   UNDESIGNATED               EMPLOYEE BENEFITS
# 417668         SUPPLIES AND MATERIALS         SPECIAL EDUCATION LOCAL
# 126378                   UNDESIGNATED                    UNDESIGNATED
# 85262      PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 304569                            NaN                             NaN
# 84272                         TEACHER           Instruction - Regular
# 64760                             NaN                             NaN
# 21870                             NaN                             NaN
# 169454                            NaN                             NaN
# 169914                            NaN                             NaN
# 189701                   UNDESIGNATED  CARE & UPKEEP OF BLDG SERVICES
# 43727                             NaN                             NaN
# 5614                              NaN                             NaN
# 307038                            NaN                             NaN
# 27645                             NaN                             NaN
# 126388             SUBSTITUTE TEACHER           Instruction - Regular
# 14962                 TEACHER -  DAYS           Instruction - Regular
# 84040                             NaN                             NaN
# 61639      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 266302     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 225768                     BUS DRIVER                   Undistributed
# 267322                   UNDESIGNATED               EMPLOYEE BENEFITS
# 308098                     BUS DRIVER                   Undistributed
# 227367                            NaN                             NaN
# 329096   CRAFTS, TRADES, AND SERVICES        FOOD PREPARATION/SERVING
# 282308                            NaN                             NaN
# ...                               ...                             ...
# 209265                    MS ENGLISH       MIDDLE SCHOOL PROGRAM  6-8
# 333748                            NaN                             NaN
# 292626         DIR EXEC DIR SECRETARY                   Undistributed
# 343458     PROFESSIONAL-INSTRUCTIONAL         OTHER GENERAL EDUCATION
# 128261     PROFESSIONAL-INSTRUCTIONAL      SPECIAL EDUCATION-TMD HIGH
# 186318     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 210652             SUBSTITUTE TEACHER              Instruction - SPED
# 340354               PARAPROFESSIONAL   GENERAL HIGH SCHOOL EDUCATION
# 435205     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 174827               PARAPROFESSIONAL    GENERAL ELEMENTARY EDUCATION
# 277504                   UNDESIGNATED               EMPLOYEE BENEFITS
# 248062                            NaN           Career And Technology
# 70455                             NaN                             NaN
# 203453                            NaN                             NaN
# 58170              SUBSTITUTE TEACHER   Support - Regular Instruction
# 68311      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 225892     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 446383                            NaN                             NaN
# 155111     RADIO & SUBSTITUTE DRIVERS                   Undistributed
# 278248                            NaN         PRIMARY GRADES PROGRAM
# 397424               PARAPROFESSIONAL  GENERAL MIDDLE/JUNIOR HIGH SCH
# 375092             SUBSTITUTE TEACHER           Instruction - Regular
# 220181       REG FOOD SERVICE WORKER                    Undistributed
# 307423                            NaN                             NaN
# 46691      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 109283                            NaN                             NaN
# 102430     PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 413949                 PARENT/TITLE I                            Misc
# 433672  OFFICE/ADMINISTRATIVE SUPPORT          MEDIA SUPPORT SERVICES
# 415831           CERTIFIED SUBSTITUTE           Accelerated Education
#
#                                          Fund_Description  \
# 134338                                       General Fund
# 326408                             General Purpose School
# 364634                                                NaN
# 47683                                                 NaN
# 229958                                                NaN
# 417668                                         LOCAL FUND
# 126378                                                NaN
# 85262                                                 NaN
# 304569                                     School to Work
# 84272                              General Purpose School
# 64760   Title I - Disadvantaged Children/Targeted Assi...
# 21870                      CONVERSION CHARTER SCHOOLS
# 169454                     GENERAL FUND
# 169914                                            General
# 189701                                                NaN
# 43727                                       Special Trust
# 5614                                        Special Trust
# 307038  Title I - Disadvantaged Children/Targeted Assi...
# 27645                      CONVERSION CHARTER SCHOOLS
# 126388                             General Purpose School
# 14962                             School Federal Projects
# 84040                                       Special Trust
# 61639                                                 NaN
# 266302                                                NaN
# 225768                             General Operating Fund
# 267322                                                NaN
# 308098                             General Operating Fund
# 227367  Title I - Disadvantaged Children/Targeted Assi...
# 329096                                                NaN
# 282308                     FOOD SERVICES
# ...                                                   ...
# 209265                                       General Fund
# 333748                                            General
# 292626                             General Operating Fund
# 343458                                                NaN
# 128261                                                NaN
# 186318                                                NaN
# 210652                            School Federal Projects
# 340354                                                NaN
# 435205                                                NaN
# 174827                                                NaN
# 277504                                                NaN
# 248062                             General Operating Fund
# 70455                      CONVERSION CHARTER SCHOOLS
# 203453                     EXTENDED LEARNING CENTER ELC
# 58170                             School Federal Projects
# 68311                                                 NaN
# 225892                                                NaN
# 446383                                      Special Trust
# 155111                             General Operating Fund
# 278248                                       General Fund
# 397424                                                NaN
# 375092                             General Purpose School
# 220181        National School Breakfast And Lunch Program
# 307423                         Miscellaneous State Grants
# 46691                                                 NaN
# 109283                     GENERAL FUND
# 102430                                                NaN
# 413949                                 Schoolwide Schools
# 433672                                                NaN
# 415831           "Title  Part A Improving Basic Programs"
#
#                                           Text_1
# 134338                                       NaN
# 326408                                       NaN
# 364634                       REGULAR INSTRUCTION
# 47683                        REGULAR INSTRUCTION
# 229958                         EMPLOYEE BENEFITS
# 417668                                       NaN
# 126378                              UNDESIGNATED
# 85262                        REGULAR INSTRUCTION
# 304569                ITEMAI-CITY-YTH EMP & OPP
# 84272                                        NaN
# 64760                                   TITLE I
# 21870                                        NaN
# 169454            TEACHER LEAD
# 169914                         SAFETY & SECURITY
# 189701              OPERATION AND MAINT OF PLANT
# 43727                      RESP SEXUAL BEHAVIOR
# 5614                        HOME TEAM MARKETING
# 307038                      BUILDING ALLOCATIONS
# 27645                                        NaN
# 126388                                       NaN
# 14962                 ESEA TITLE I DISADVANTAGED
# 84040                  KEY BANK NATIONAL ASSOCIA
# 61639                        INSTRUCTIONAL STAFF
# 266302                       REGULAR INSTRUCTION
# 225768             ADDL REGULAR PAY-NOT SMOOTHED
# 267322                         EMPLOYEE BENEFITS
# 308098                                  OVERTIME
# 227367                 TITLE I - PARENT INVOLVEM
# 329096                  FOOD SERVICES OPERATIONS
# 282308                                       NaN
# ...                                          ...
# 209265                                       NaN
# 333748                    PSYCHOLOGICAL SERVICES
# 292626                                  OVERTIME
# 343458                       REGULAR INSTRUCTION
# 128261                         SPECIAL EDUCATION
# 186318                       REGULAR INSTRUCTION
# 210652  INDIVIDUALS WITH DISABILITIES ACT PART B
# 340354                       REGULAR INSTRUCTION
# 435205                       REGULAR INSTRUCTION
# 174827                       REGULAR INSTRUCTION
# 277504                         EMPLOYEE BENEFITS
# 248062                                       NaN
# 70455                                        NaN
# 203453                                       NaN
# 58170                                      OTHER
# 68311                        INSTRUCTIONAL STAFF
# 225892                       REGULAR INSTRUCTION
# 446383                    ITEMS FOUNDATION-JUNE
# 155111                                  OVERTIME
# 278248                                       NaN
# 397424                       REGULAR INSTRUCTION
# 375092                                       NaN
# 220181                               REGULAR PAY
# 307423                  SCHOOL IMPROV INCENTIVES
# 46691                        INSTRUCTIONAL STAFF
# 109283            STAFF DEV AND INSTR MEDIA
# 102430                       INSTRUCTIONAL STAFF
# 413949                                       NaN
# 433672                       INSTRUCTIONAL STAFF
# 415831                            MISCELLANEOUS
#
# [320222 rows x 14 columns]
#
#
#  THE SHAPE OF NEW TEXT DATA
# --------------------
#
#
# (320222, 14)
#
#
# Now the New TEXT DATA IS:
# -----------------------------
#
#
#
#                                        Object_Description  \
# 134338
# 326408                       Personal Services - Teachers
# 364634                                  EMPLOYEE BENEFITS
# 47683                        TEACHER COVERAGE FOR TEACHER
# 229958                                    CONTRA BENEFITS
# 417668                                        EDUCATIONAL
# 126378                                  EMPLOYEE BENEFITS
# 85262                                   EMPLOYEE BENEFITS
# 304569                                        EQUIPMENT *
# 84272                        Personal Services - Teachers
# 64760                                           Regular *
# 21870                      OTHER PERSONAL SERVICES
# 169454                     SUPPLIES
# 169914                                          Regular *
# 189701                                        ELECTRICITY
# 43727               Non-Certificated Travel Reimbursement
# 5614                                   Purchased Services
# 307038                                          Regular *
# 27645                      BONUSES
# 126388  Personal Services - Substitute Teachers Certified
# 14962                        Personal Services - Teachers
# 84040                                         EQUIPMENT *
# 61639                                   EMPLOYEE BENEFITS
# 266302                                  EMPLOYEE BENEFITS
# 225768      Extra Duty Pay/Overtime For Support Personnel
# 267322                                    CONTRA BENEFITS
# 308098      Extra Duty Pay/Overtime For Support Personnel
# 227367                                 Purchased Services
# 329096                      SALARIES OF REGULAR EMPLOYEES
# 282308                     OTHER SUPPORT PERSONNEL
# ...                                                   ...
# 209265
# 333748                                          Regular *
# 292626      Extra Duty Pay/Overtime For Support Personnel
# 343458                     SALARIES OF PART TIME EMPLOYEE
# 128261                      SALARIES OF REGULAR EMPLOYEES
# 186318                      SALARIES OF REGULAR EMPLOYEES
# 210652  Personal Services - Substitute Teachers Non-Ce...
# 340354                                  EMPLOYEE BENEFITS
# 435205                       EMPLOYER PD MED CONTRIBUTION
# 174827                     SALARIES OF PART TIME EMPLOYEE
# 277504                                    CONTRA BENEFITS
# 248062             Travel And Subsistence - Employee Only
# 70455                      CLASSROOM TEACHER
# 203453                     IN-COUNTY TRAVEL
# 58170   Personal Services - Substitute Teachers Certified
# 68311                      ADDITIONAL/EXTRA DUTY PAY/STIP
# 225892                      SALARIES OF REGULAR EMPLOYEES
# 446383                Other Pupil Transportation Services
# 155111      Extra Duty Pay/Overtime For Support Personnel
# 278248                                           SUPPLIES
# 397424                     ADDITIONAL/EXTRA DUTY PAY/STIP
# 375092  Personal Services - Substitute Teachers Certified
# 220181            Salaries Or Wages For Support Personnel
# 307423                            Other Awards and Prizes
# 46691                      ADDITIONAL/EXTRA DUTY PAY/STIP
# 109283                     WORKSHOP PARTICIPANT
# 102430                     SALARIES OF PART TIME EMPLOYEE
# 413949
# 433672                                  EMPLOYEE BENEFITS
# 415831    Salaries And Wages For Substitute Professionals
#
#                                Text_2  \
# 134338
# 326408
# 364634                   TEACHER SUBS
# 47683                    TEACHER SUBS
# 229958
# 417668  SPECIAL EDUCATION INSTRUCTION
# 126378
# 85262                    TEACHER SUBS
# 304569
# 84272
# 64760
# 21870
# 169454
# 169914                       ADM/PROF
# 189701         OPERATIONS - UTILITIES
# 43727
# 5614
# 307038                        TEACHER
# 27645
# 126388
# 14962
# 84040
# 61639
# 266302
# 225768
# 267322
# 308098
# 227367
# 329096                  FOOD SERVICES
# 282308
# ...                               ...
# 209265
# 333748                     TEACHERSUP
# 292626
# 343458                   TEACHER SUBS
# 128261            SEVERE DISABILITIES
# 186318
# 210652
# 340354
# 435205
# 174827
# 277504
# 248062
# 70455
# 203453
# 58170
# 68311                    MATH/SCIENCE
# 225892
# 446383
# ...
# ent
# enterprise
# enterprs
# entrprs
# entry
# env
# enviro
# environmental
# envision
# envrmntl
# epa
# equip
# equipmen
# equipment
# equipmnt
# equivalent
# er
# ercm
# ers
# es
# esc
# esco
# escrow
# ese
# esea
# esernv
# esl
# esol
# estate
# esthetician
# esy
# etc
# etech
# ets
# eval
# evaluati
# evaluation
# evaluations
# evaluator
# eve
# even
# event
# events
# every
# ex
# exam
# examinations
# examiner
# exceeding
# excelerator
# excellence
# except
# exception
# exceptional
# excess
# excl
# exe
# exec
# executive
# exempt
# exeter
# exp
# expand
# expanded
# expanding
# expans
# expansion
# expectations
# expelled
# expendable
# expenditures
# expense
# expenses
# exper
# experience
# expert
# exploration
# exploring
# ext
# extended
# external
# extg
# extra
# extracurricula
# extracurricular
# f
# face
# facilitato
# facilitator
# facilites
# facilities
# facility
# facing
# facsimile
# faculty
# fair
# fairfax
# fall
# fam
# fame
# families
# family
# famly
# fapt
# farm
# fasd
# fast
# faster
# fd
# fdlrs
# fdn
# fdtn
# feb
# fed
# federal
# fee
# feed
# feeding
# fees
# fefp
# fellows
# female
# fencing
# festival
# ffe
# fica
# field
# fifth
# file
# films
# filmstrips
# fin
# finalist
# finan
# finance
# financial
# finch
# find
# fine
# fingerprinting
# fire
# first
# fiscal
# fitfun
# fitness
# five
# fix
# fixed
# fixtures
# flag
# flats
# fleet
# flex
# flexible
# floor
# flow
# flowthrough
# flowthru
# fluids
# fnd
# focus
# food
# foods
# foodsrv
# foodsvc
# football
# for
# foreign
# foreman
# forensics
# forms
# formula
# forng
# forum
# found
# foundat
# foundation
# foundations
# fourth
# free
# freight
# french
# fresh
# friends
# from
# fruit
# fs
# fsd
# fsfoa
# fss
# ft
# fte
# fuel
# fuels
# full
# function
# functions
# fund
# fundamental
# fundamentals
# funded
# funding
# funds
# furnishing
# furniture
# fuse
# future
# futures
# fvs
# fy
# fyii
# g
# game
# gap
# garage
# garageman
# garbage
# garden
# gardner
# garfield
# gas
# gasoline
# gator
# gdpg
# ge
# ged
# gelber
# gems
# gen
# gender
# general
# generalist
# generator
# generic
# genl
# geographic
# geography
# geometry
# george
# german
# gesp
# get
# gi
# gifted
# gir
# girl
# girls
# giver
# glass
# glazier
# global
# gnets
# goal
# goals
# gob
# golf
# good
# got
# governance
# governmental
# gr
# grad
# grade
# grades
# grads
# graduate
# graduation
# graftech
# grant
# grants
# graphic
# grass
# grasscutters
# gratuities
# grease
# great
# green
# grnt
# gross
# grounds
# groundworks
# group
# groupings
# groups
# grow
# grown
# growth
# grp
# grt
# grwpln
# gt
# guard
# guards
# guid
# guidance
# guitar
# gvr
# gymnastics
# h
# habitat
# handicapped
# handicaps
# hands
# hannah
# harass
# hardw
# hardware
# harvard
# hat
# hate
# hats
# hay
# hazardous
# hazmat
# hb
# hbsc
# hd
# hdc
# he
# hea
# head
# headstar
# headstart
# healt
# health
# healthier
# healthiest
# healthly
# healthy
# healty
# hear
# hearing
# hearings
# heart
# heating
# heavy
# heights
# held
# help
# helper
# hhs
# hi
# high
# higher
# highly
# highway
# hire
# hist
# history
# hlth
# hmn
# hndcpd
# hof
# holding
# holiday
# home
# homebased
# homebound
# homegrown
# homeless
# homework
# horticulture
# hospital
# hospitality
# hospitals
# host
# hosts
# hour
# hourly
# hous
# house
# hqt
# hr
# hris
# hrly
# hrs
# hs
# hsbc
# hst
# hub
# hubs
# human
# humanities
# humanware
# hurricane
# hvac
# hvy
# hydronic
# hygiene
# i
# ia
# iaf
# ib
# id
# idea
# ii
# iia
# iid
# iii
# ikon
# imagination
# immigrant
# immunization
# imp
# impact
# impaired
# impairment
# implement
# implementation
# imporvoment
# improv
# improve
# improved
# improvement
# improvements
# improving
# improvmt
# in
# inactive
# inc
# incarcerated
# incentive
# incentives
# including
# inclusion
# inclusive
# income
# increment
# independent
# indian
# indirect
# indiv
# individual
# individuals
# induction
# indust
# industrial
# industries
# industry
# industy
# inf
# info
# infor
# inform
# information
# infra
# inheriting
# iniative
# ininerant
# init
# initiative
# initiatives
# initiatvs
# inner
# inno
# innov
# innovation
# innovations
# innovative
# ins
# inservice
# inspector
# inst
# installation
# installations
# installer
# institut
# institute
# institutions
# instnl
# instr
# instrc
# instrctn
# instruc
# instruct
# instruction
# instructional
# instructn
# instructor
# instrument
# instrumental
# instruments
# insulator
# insuranc
# insurance
# int
# integr
# integrated
# integration
# intel
# intell
# intellect
# intellectually
# intelligence
# intensive
# intentional
# inter
# interactive
# interagy
# interdisciplinary
# interest
# interfund
# intergov
# intergovernmental
# interim
# interm
# intermediate
# intern
# internal
# international
# internet
# internl
# interntl
# interpreter
# interrelated
# interscholastic
# interv
# interve
# intervent
# intervention
# interventions
# intg
# intl
# intr
# intradistrict
# intramural
# intrn
# intructional
# intrvnt
# ints
# inv
# invent
# inventory
# invest
# investigation
# investigative
# investigator
# investment
# invntry
# involvement
# involvment
# involvmt
# ipd
# irc
# ironworker
# irrig
# irrigation
# is
# isef
# isp
# iss
# issn
# issuance
# issue
# issues
# ist
# it
# ita
# item
# itema
# itemaa
# itemab
# itemac
# itemad
# itemae
# itemaf
# itemag
# itemai
# itemb
# itemc
# itemd
# iteme
# itemfa
# itemfb
# itemfc
# itemfccentral
# itemfcco
# itemfd
# itemfe
# itemfh
# itemg
# itemga
# itemgb
# itemgc
# itemgd
# itemge
# itemgf
# itemgh
# itemgi
# itemha
# itemhb
# itemi
# itemj
# itemk
# itemn
# itemo
# itemp
# itempp
# itempq
# itemr
# items
# itemt
# itemu
# itemv
# itemwz
# itemx
# itemy
# itemya
# itemz
# itinerant
# itinerate
# itl
# iv
# j
# jail
# janitor
# janitorial
# japanese
# jcf
# jf
# jhs
# job
# jobs
# john
# journalism
# jr
# jrotc
# judgments
# july
# jump
# jun
# june
# junior
# justice
# juvenile
# jv
# k
# k12
# kappa
# kdg
# key
# keybank
# keycorp
# keys
# kg
# kidergarten
# kids
# kind
# kinder
# kinderagrten
# kindergar
# kindergart
# kindergarten
# kindergatn
# kindrng
# kitchen
# kndgarten
# kng
# knowledge
# l
# lab
# labor
# laboratory
# laborer
# lacrosse
# ladder
# land
# lang
# langs
# language
# languages
# lanschool
# large
# latin
# laundry
# law
# lawyer
# lay
# layered
# ld
# ldbd
# ldrshp
# lea
# lead
# leader
# leaders
# leadership
# leading
# leadman
# league
# leagues
# learn
# learners
# learning
# leas
# lease
# leased
# leasehold
# leases
# leave
# leaves
# led
# ledger
# legacy
# legal
# legislative
# legl
# leisure
# lep
# less
# let
# level
# levy
# lfi
# liability
# liaison
# liaisons
# liason
# liasons
# libraian
# librarian
# librarians
# library
# lic
# license
# licensed
# licensure
# liceracy
# lieutenant
# life
# lightning
# lights
# limited
# line
# link
# linkage
# lit
# literacy
# literary
# ll
# lli
# lmc
# lng
# loans
# local
# locally
# locks
# locksmith
# logistics
# long
# loss
# lotc
# lottery
# lower
# lpn
# lrn
# lrng
# lsta
# lts
# lunch
# lunches
# lunchroom
# lung
# lutheran
# lv
# lvl
# lw
# m
# maanger
# mach
# machine
# machinery
# machines
# mag
# magement
# magnet
# mail
# mailroom
# main
# mainenance
# mainstream
# maint
# maintance
# maintenacne
# maintenance
# maison
# maj
# major
# majr
# make
# making
# mala
# male
# mallet
# man
# manag
# manage
# managed
# managemen
# management
# managemnt
# manager
# mandel
# mang
# manger
# manual
# manufacturing
# map
# maps
# marching
# marion
# marketing
# marsh
# marzano
# mason
# masonry
# mast
# master
# match
# matenance
# material
# materials
# math
# mathematics
# mather
# matls
# matrls
# matters
# may
# mcdonald
# md
# mdta
# me
# measures
# meat
# mech
# mechanic
# mechanics
# med
# media
# mediation
# medicaid
# medical
# medicare
# meeting
# meetings
# mem
# member
# members
# memberships
# memo
# memorial
# men
# mental
# mentally
# mentor
# mentoring
# mentors
# mentorship
# mesa
# messenger
# metal
# metro
# mgmt
# mgr
# mgt
# mhuw
# mid
# midd
# middle
# migrant
# mil
# mild
# mildly
# mileage
# miles
# military
# milk
# mill
# millage
# millwright
# mimh
# min
# mind
# mini
# minor
# minority
# minute
# mis
# misc
# miscellaneous
# miscellenous
# misical
# mixed
# mngr
# mntl
# mo
# mobile
# mobility
# moc
# model
# moderate
# modification
# mon
# monitor
# monitoring
# monitors
# montessori
# month
# months
# montsorri
# more
# motor
# move
# moveable
# ms
# msp
# mstr
# msu
# mtce
# mtl
# mtrls
# mttrs
# multi
# multicult
# multicultural
# multihandicapped
# multilingual
# museum
# music
# musical
# mutual
# mycom
# n
# nasa
# nat
# national
# natl
# natural
# nbpts
# nc
# ncert
# nclb
# nclusion
# ne
# need
# needs
# neg
# negl
# neglected
# negotiation
# negotiations
# neighborhood
# neighborhoods
# neighbrhd
# net
# netwk
# network
# networks
# new
# newcomer
# news
# newspaper
# newspapers
# next
# nfac
# nfl
# night
# nights
# nike
# ninth
# no
# non
# nonathletic
# nonbenefitted
# noncapitalized
# noncert
# none
# nonpublic
# nonresident
# north
# not
# notification
# nov
# np
# ns
# nsba
# nsta
# ntnl
# ntwk
# number
# numeracy
# nurse
# nursery
# nurses
# nursing
# nutrition
# nutritionfacilitator
# nutritionist
# nw
# nwcnfrn
# o
# oai
# oaks
# objective
# objects
# observer
# obsolete
# occ
# occp
# occupancy
# occupational
# occupations
# octo
# october
# odnr
# of
# ofc
# ofcr
# off
# offi
# office
# officemax
# officer
# officers
# official
# officials
# offr
# offset
# ogt
# oh
# ohio
# ohsti
# oi
# oil
# old
# olympics
# ombudsman
# on
# one
# onis
# online
# only
# onthe
# op
# open
# opening
# openings
# oper
# operated
# operating
# operation
# operations
# operatns
# operator
# opp
# opportunity
# ops
# optical
# optional
# options
# or
# orchestra
# org
# organization
# organizational
# orientation
# oriented
# orl
# orthopedically
# ose
# ospr
# ot
# oth
# other
# others
# othr
# our
# out
# outdoor
# outlay
# outlays
# outrch
# outreach
# outside
# ovac
# override
# oversight
# overtime
# oye
# p
# pac
# pack
# padas
# paid
# paint
# painter
# painting
# paintng
# panasonic
# paperback
# para
# paralegal
# parapro
# paraprof
# paraprofessional
# paraprofessionals
# parent
# parental
# parenting
# parents
# parking
# parnt
# part
# partially
# participant
# participants
# participation
# participatory
# partne
# partner
# partners
# partnershi
# partnership
# partnerships
# parts
# party
# passroom
# path
# pathologist
# pathologists
# pathologst
# pathology
# paths
# pathways
# patrol
# pavement
# pay
# payable
# payment
# payments
# payout
# payroll
# pc
# pd
# pe
# pedagogy
# pedestrian
# peer
# pell
# pension
# people
# pep
# pepsi
# per
# percussion
# perf
# perfomance
# performance
# performing
# periodic
# periodicals
# perishable
# perkins
# perm
# permanent
# person
# personal
# personnel
# pest
# pgm
# pgms
# ph
# phase
# phi
# philliber
# photography
# phy
# phys
# physical
# physics
# pilot
# pioneer
# pk
# pl
# place
# placement
# placements
# plan
# plancement
# planetarium
# planner
# planning
# plant
# plasterer
# plato
# play
# playgrd
# playground
# playoff
# plcmnt
# plcmt
# plot
# plumber
# plumbing
# plus
# pmt
# pnsca
# podcasting
# point
# police
# policy
# political
# pool
# pools
# populations
# porgram
# portable
# portables
# portal
# portble
# portfolio
# position
# positive
# positoin
# positon
# post
# postage
# postsecondary
# potential
# power
# ppg
# pr
# practical
# practice
# praxis
# pre
# preformance
# pregnancy
# prek
# prekindergarten
# premium
# premiums
# prep
# preparation
# preparing
# presch
# preschool
# prescl
# prescriptions
# president
# press
# prevent
# prevention
# prg
# prgm
# prgms
# prgram
# prgrm
# price
# prim
# primary
# prin
# principal
# principals
# prinicp
# print
# printer
# printers
# printing
# printshop
# prior
# priority
# private
# prizes
# prjt
# prnt
# pro
# proc
# process
# processing
# processor
# procurement
# product
# production
# products
# prof
# professi
# professiona
# professional
# professionals
# proficiency
# proficient
# profits
# profnd
# prog
# progr
# program
# programmatic
# programmer
# programming
# programs
# progrm
# progrming
# progs
# proj
# project
# projects
# promotion
# prop
# property
# protech
# protective
# protectv
# prov
# provide
# provided
# provider
# provisions
# prt
# prtble
# prvntn
# pschologist
# pshycologist
# psp
# psy
# psych
# psychological
# psychologist
# psychologists
# psychometrician
# psycologist
# pt
# pta
# ptr
# public
# publications
# pump
# pup
# pupil
# pupils
# purch
# purchase
# purchased
# purchases
# purchasing
# purpose
# purposes
# qa
# qbe
# qc
# qualified
# qualit
# quality
# qualty
# quest
# qwest
# r
# race
# radio
# raising
# ranch
# rate
# rates
# rbi
# rd
# rdg
# re
# read
# readi
# readiness
# reading
# ready
# real
# realoc
# realty
# rec
# receiver
# receives
# receiving
# receptionist
# reclassified
# recognition
# records
# recovery
# recreational
# recruiter
# recruiting
# recruitment
# recycling
# red
# redemption
# reduction
# ref
# reference
# referral
# reform
# refrigeration
# refugee
# refugees
# refunded
# refunding
# refunds
# reg
# region
# regional
# registrar
# registration
# regular
# regulr
# reim
# reimbur
# reimbursable
# reimbursement
# reimbursements
# reinsurance
# rel
# relatated
# related
# relation
# relations
# release
# relief
# remaining
# remedial
# remediation
# remodel
# remodeling
# removal
# renewal
# renov
# renovation
# renovations
# rent
# rental
# rentals
# renv
# rep
# repair
# repairs
# repl
# replacement
# report
# reporting
# reports
# reprod
# req
# reqd
# require
# res
# resale
# research
# reserve
# reserved
# reside
# residency
# resident
# residential
# reso
# resolution
# resource
# resources
# resourcs
# resp
# respon
# respons
# response
# responsible
# restaurant
# restorative
# restr
# restructuring
# results
# retarded
# retention
# retired
# retiree
# retirement
# retrd
# retreat
# retrofif
# retrofit
# return
# rev
# revenue
# review
# revitalization
# rgn
# ribbon
# rifle
# right
# risk
# rite
# rn
# rnvsafesc
# robotics
# rock
# rocks
# rode
# rollup
# ronald
# roof
# roofer
# roofing
# room
# rotary
# rotc
# round
# roundup
# route
# router
# routing
# rpm
# rpr
# rsb
# rsrc
# rt
# rtd
# rte
# rti
# rtrs
# rttp
# rttt
# runs
# s
# sac
# safe
# safety
# saftey
# sai
# sal
# salaried
# salaries
# salary
# sale
# sales
# sams
# sanitation
# sasi
# sat
# satellite
# saturda
# saturday
# savings
# sc
# sch
# sched
# scheduler
# schl
# schls
# scholar
# scholars
# scholarship
# scholarships
# schoo
# school
# schooled
# schoolnet
# schools
# schoolwide
# sci
# science
# sciences
# scl
# scnd
# scndy
# scoial
# screening
# scrty
# se
# seas
# sec
# secetary
# second
# secondary
# secretaries
# secretary
# sectio
# section
# secure
# security
# sel
# selection
# self
# senior
# seniors
# sep
# sepcial
# sept
# sequence
# ser
# serg
# sergeant
# serial
# series
# serv
# serve
# servi
# servic
# service
# services
# servicing
# serving
# servs
# ses
# set
# settlement
# severe
# severely
# sewage
# sewer
# sewerman
# sews
# sex
# sexual
# sfpc
# sftball
# sftwre
# sh
# sha
# shakespeare
# share
# shared
# sharepoint
# sheet
# sheetmtl
# sheets
# shell
# shelter
# sheltered
# sherwin
# shift
# shipping
# shop
# short
# show
# showcase
# shrt
# shs
# si
# sick
# side
# sig
# sighted
# sign
# significant
# sim
# similar
# sip
# sis
# site
# size
# skill
# skills
# sl
# small
# smaller
# smart
# sme
# smed
# smh
# snack
# snacks
# sns
# soc
# soccer
# social
# society
# softall
# softball
# software
# sol
# sold
# solid
# solution
# solutions
# sound
# sourc
# sources
# south
# southern
# sp
# space
# spanish
# speakers
# speaki
# spec
# speced
# specia
# special
# specialis
# specialist
# specials
# specialsit
# specific
# speclst
# spectrum
# sped
# speech
# spending
# spo
# sponsor
# sponsorship
# sport
# sports
# spring
# sql
# square
# sr
# srv
# srvcs
# ss
# st
# stabilitazion
# stabilization
# stadium
# staff
# staffing
# stage
# stages
# stand
# standard
# standards
# staples
# star
# starbucks
# start
# starting
# startup
# state
# statistical
# statistician
# stdnt
# stds
# steam
# steamfitter
# steele
# stem
# stems
# step
# steps
# sterling
# stim
# stimulus
# stip
# stock
# stone
# store
# strands
# strat
# strategic
# strategies
# strategist
# strategy
# stratey
# stratigic
# street
# strengthening
# stretch
# string
# strt
# structural
# structured
# structures
# stu
# stud
# student
# students
# studies
# studnt
# study
# sub
# subclass
# subcontract
# subject
# submissions
# subpart
# subs
# subscription
# subscriptions
# subsidies
# subsidy
# subsistence
# subst
# substitute
# substitutes
# subteacher
# succeed
# success
# sufficient
# sum
# summ
# summer
# summit
# suncorp
# sunday
# sundries
# sup
# supensio
# super
# superintendent
# superintendents
# superintentents
# supervision
# supervisor
# supervisors
# supervisory
# supl
# supp
# supper
# suppl
# supplement
# supplemental
# supplements
# supplies
# suppliment
# supplimental
# supply
# suppor
# support
# supporting
# supportive
# suppression
# suppt
# supt
# supv
# surgical
# surrogate
# suspen
# sustainability
# sustainabilty
# svc
# svcs
# sw
# swap
# sweeper
# sweepers
# swim
# swimming
# swing
# symposium
# sys
# syst
# system
# systems
# systemwide
# sytms
# t
# ta
# tabacco
# tag
# tagging
# take
# talented
# tanf
# tap
# tapestry
# taps
# targ
# target
# targeted
# targt
# tax
# taxes
# taylor
# tch
# tcher
# tchr
# tchracct
# tchrs
# tea
# teach
# teacher
# teachers
# teachersup
# teaching
# team
# teams
# tech
# techician
# technical
# technician
# technicians
# technlgies
# technlogie
# technol
# technolgies
# technolog
# technologist
# technology
# teen
# telecom
# telecommunication
# telephone
# temp
# temporary
# temps
# tennis
# term
# terminal
# terminated
# test
# tester
# testing
# tests
# text
# textbook
# textbooks
# than
# that
# thats
# the
# thearpy
# theater
# their
# therap
# therapeutic
# therapist
# therapists
# therapy
# therp
# thinking
# third
# three
# thriving
# thro
# through
# thru
# ti
# ticket
# tif
# tile
# time
# timecard
# tinner
# tip
# tires
# title
# tmd
# tmo
# tn
# to
# tobacco
# tomorrow
# tool
# toolkit
# toolroom
# top
# tosas
# tournament
# track
# trade
# trades
# traffic
# train
# trainee
# trainer
# trainier
# training
# trans
# transfe
# transfer
# transfers
# transformation
# transisition
# transition
# transitory
# translation
# translator
# transp
# transport
# transportaion
# transportation
# transportion
# travel
# traveling
# treasurer
# treasury
# treatment
# trip
# trips
# trng
# trnr
# tru
# truancy
# truant
# truck
# trust
# trw
# tst
# tti
# ttl
# tubes
# tuition
# turn
# turnaround
# turning
# tutor
# tutorial
# tutoring
# tv
# twenty
# twice
# twilight
# typing
# typist
# ub
# unalloc
# unallocated
# unassigned
# under
# undesignated
# undistributed
# unemployment
# uni
# unicare
# uniform
# uniforms
# union
# unit
# united
# univ
# university
# unused
# up
# upgrade
# upgrades
# upk
# upkeep
# upper
# urban
# urog
# us
# usage
# usda
# use
# used
# uses
# using
# utilities
# v
# vacation
# var
# variable
# variance
# various
# ve
# vegetable
# vegetables
# veggie
# vegrtables
# vehicle
# vehicles
# vend
# vending
# vendor
# vendors
# verification
# vertical
# vesp
# vi
# via
# vib
# vice
# video
# videographer
# violence
# violin
# virtual
# vision
# visiting
# visual
# visually
# vndg
# voc
# vocal
# vocational
# voe
# voices
# voip
# volleyball
# volleybally
# voluntary
# volunteer
# votec
# voyager
# vpk
# wae
# wages
# waiting
# wall
# wallace
# warehouse
# warehousing
# warm
# was
# wash
# waste
# wastewater
# water
# wave
# way
# wc
# wealth
# web
# webinars
# webmaster
# week
# weekend
# welcome
# welding
# wellness
# wf
# when
# white
# whiz
# who
# whse
# wide
# wildlife
# will
# williams
# wingspread
# wired
# with
# within
# wk
# wkr
# work
# worke
# worker
# workers
# workforce
# working
# works
# workshop
# workshops
# workstudy
# world
# wrestling
# wrhs
# write
# writer
# writing
# wrk
# wsd
# x
# xcurricluar
# xpay
# yard
# year
# years
# yellow
# ymca
# young
# your
# youth
# yr
# yrs
# yth
# z
# zeta
# zuni

# %%
df
# Out:
#                                                Function          Use  \
# 134338                             Teacher Compensation  Instruction
# 206341                                         NO_LABEL     NO_LABEL
# 326408                             Teacher Compensation  Instruction
# 364634                          Substitute Compensation  Instruction
# 47683                           Substitute Compensation  Instruction
# 229958                         Facilities & Maintenance          O&M
# 417668               Instructional Materials & Supplies  Instruction
# 126378                                    Food Services          O&M
# 275539                             Teacher Compensation  Instruction
# 85262                           Substitute Compensation  Instruction
# 304569                                         NO_LABEL     NO_LABEL
# 330504               Instructional Materials & Supplies  Instruction
# 84272                              Teacher Compensation  Instruction
# 64760                                          NO_LABEL     NO_LABEL
# 21870                                          NO_LABEL     NO_LABEL
# 18698                           Substitute Compensation  Instruction
# 169454               Instructional Materials & Supplies  Instruction
# 169914                                Security & Safety          O&M
# 189701                                        Utilities          O&M
# 43727                                          NO_LABEL     NO_LABEL
# 5614                                           NO_LABEL     NO_LABEL
# 291539                          Substitute Compensation  Instruction
# 307038                             Teacher Compensation  Instruction
# 27645                                          NO_LABEL     NO_LABEL
# 126388                          Substitute Compensation  Instruction
# 14962                              Teacher Compensation  Instruction
# 84040                                          NO_LABEL     NO_LABEL
# 61639                           Substitute Compensation  Instruction
# 266302                             Teacher Compensation  Instruction
# 225768                           Student Transportation          O&M
# ...                                                 ...          ...
# 333748  Special Population Program Management & Support         ISPD
# 292626                                         NO_LABEL     NO_LABEL
# 343458                          Substitute Compensation  Instruction
# 128261                             Teacher Compensation  Instruction
# 186318                             Teacher Compensation  Instruction
# 210652                          Substitute Compensation  Instruction
# 340354                               Aides Compensation  Instruction
# 435205                             Teacher Compensation  Instruction
# 174827                               Aides Compensation  Instruction
# 277504                             Teacher Compensation  Instruction
# 248062                         Professional Development         ISPD
# 70455                                          NO_LABEL     NO_LABEL
# 203453                                         NO_LABEL     NO_LABEL
# 58170                           Substitute Compensation  Instruction
# 72072                             School Administration   Leadership
# 68311                              Teacher Compensation  Instruction
# 225892                             Teacher Compensation  Instruction
# 446383                                         NO_LABEL     NO_LABEL
# 155111                           Student Transportation          O&M
# 278248               Instructional Materials & Supplies  Instruction
# 397424                                         NO_LABEL     NO_LABEL
# 375092                          Substitute Compensation  Instruction
# 220181                                    Food Services          O&M
# 307423                                         NO_LABEL     NO_LABEL
# 46691                              Teacher Compensation  Instruction
# 109283                         Professional Development         ISPD
# 102430                          Substitute Compensation  Instruction
# 413949                     Parent & Community Relations     NO_LABEL
# 433672                                  Library & Media  Instruction
# 415831                          Substitute Compensation  Instruction
#
#                           Sharing   Reporting       Student_Type  \
# 134338            School Reported      School           NO_LABEL
# 206341                   NO_LABEL    NO_LABEL           NO_LABEL
# 326408            School Reported      School        Unspecified
# 364634            School Reported      School        Unspecified
# 47683             School Reported      School        Unspecified
# 229958            School Reported      School        Unspecified
# 417668            School Reported      School  Special Education
# 126378  School on Central Budgets  Non-School        Unspecified
# 275539            School Reported      School        Unspecified
# 85262             School Reported      School        Unspecified
# 304569                   NO_LABEL    NO_LABEL           NO_LABEL
# 330504            School Reported      School           NO_LABEL
# 84272             School Reported      School        Unspecified
# 64760                    NO_LABEL    NO_LABEL           NO_LABEL
# 21870                    NO_LABEL    NO_LABEL           NO_LABEL
# 18698             School Reported      School        Unspecified
# 169454            School Reported      School            Poverty
# 169914    Leadership & Management  Non-School        Unspecified
# 189701            School Reported      School        Unspecified
# 43727                    NO_LABEL    NO_LABEL           NO_LABEL
# 5614                     NO_LABEL    NO_LABEL           NO_LABEL
# 291539            School Reported      School        Unspecified
# 307038            School Reported      School            Poverty
# 27645                    NO_LABEL    NO_LABEL           NO_LABEL
# 126388            School Reported      School        Unspecified
# 14962             School Reported      School            Poverty
# 84040                    NO_LABEL    NO_LABEL           NO_LABEL
# 61639             School Reported      School        Unspecified
# 266302            School Reported      School        Unspecified
# 225768            Shared Services  Non-School        Unspecified
# ...                           ...         ...                ...
# 333748  School on Central Budgets  Non-School  Special Education
# 292626                   NO_LABEL    NO_LABEL           NO_LABEL
# 343458  School on Central Budgets  Non-School        Unspecified
# 128261            School Reported      School  Special Education
# 186318            School Reported      School        Unspecified
# 210652            School Reported      School  Special Education
# 340354            School Reported      School                ELL
# 435205            School Reported      School        Unspecified
# 174827            School Reported      School                ELL
# 277504            School Reported      School        Unspecified
# 248062            School Reported      School        Unspecified
# 70455                    NO_LABEL    NO_LABEL           NO_LABEL
# 203453                   NO_LABEL    NO_LABEL           NO_LABEL
# 58170             School Reported      School        Unspecified
# 72072             School Reported      School        Unspecified
# 68311   School on Central Budgets  Non-School        Unspecified
# 225892            School Reported      School        Unspecified
# 446383                   NO_LABEL    NO_LABEL           NO_LABEL
# 155111            Shared Services  Non-School        Unspecified
# 278248            School Reported      School           NO_LABEL
# 397424                   NO_LABEL    NO_LABEL           NO_LABEL
# 375092            School Reported      School        Unspecified
# 220181            Shared Services      School        Unspecified
# 307423                   NO_LABEL    NO_LABEL           NO_LABEL
# 46691   School on Central Budgets  Non-School        Unspecified
# 109283            Shared Services  Non-School        Unspecified
# 102430            School Reported      School        Unspecified
# 413949            School Reported      School           NO_LABEL
# 433672  School on Central Budgets  Non-School        Unspecified
# 415831            School Reported      School            Poverty
#
#               Position_Type                 Object_Type     Pre_K  \
# 134338              Teacher                    NO_LABEL  NO_LABEL
# 206341             NO_LABEL                    NO_LABEL  NO_LABEL
# 326408              Teacher    Base Salary/Compensation  Non PreK
# 364634           Substitute                    Benefits  NO_LABEL
# 47683               Teacher     Substitute Compensation  NO_LABEL
# 229958            Custodian                    Benefits  NO_LABEL
# 417668         Non-Position          Supplies/Materials  NO_LABEL
# 126378  Coordinator/Manager                    Benefits  NO_LABEL
# 275539              Teacher                    Benefits  NO_LABEL
# 85262            Substitute                    Benefits  NO_LABEL
# 304569             NO_LABEL                    NO_LABEL  NO_LABEL
# 330504             NO_LABEL          Supplies/Materials  NO_LABEL
# 84272               Teacher    Base Salary/Compensation  Non PreK
# 64760              NO_LABEL                    NO_LABEL  NO_LABEL
# 21870              NO_LABEL                    NO_LABEL  NO_LABEL
# 18698            Substitute     Substitute Compensation  Non PreK
# 169454             NO_LABEL          Supplies/Materials  NO_LABEL
# 169914                Other    Base Salary/Compensation  Non PreK
# 189701         Non-Position              Rent/Utilities  NO_LABEL
# 43727              NO_LABEL                    NO_LABEL  NO_LABEL
# 5614               NO_LABEL                    NO_LABEL  NO_LABEL
# 291539           Substitute    Base Salary/Compensation  NO_LABEL
# 307038              Teacher    Base Salary/Compensation  Non PreK
# 27645              NO_LABEL                    NO_LABEL  NO_LABEL
# 126388           Substitute     Substitute Compensation  Non PreK
# 14962               Teacher    Base Salary/Compensation  Non PreK
# 84040              NO_LABEL                    NO_LABEL  NO_LABEL
# 61639            Substitute                    Benefits  NO_LABEL
# 266302              Teacher                    Benefits  NO_LABEL
# 225768                Other  Other Compensation/Stipend  Non PreK
# ...                     ...                         ...       ...
# 333748         Psychologist    Base Salary/Compensation  Non PreK
# 292626             NO_LABEL                    NO_LABEL  NO_LABEL
# 343458           Substitute    Base Salary/Compensation  NO_LABEL
# 128261              Teacher    Base Salary/Compensation  NO_LABEL
# 186318              Teacher    Base Salary/Compensation  NO_LABEL
# 210652           Substitute     Substitute Compensation  Non PreK
# 340354                   TA                    Benefits  NO_LABEL
# 435205              Teacher                    Benefits  NO_LABEL
# 174827                   TA    Base Salary/Compensation  NO_LABEL
# 277504              Teacher                    Benefits  NO_LABEL
# 248062             NO_LABEL        Travel & Conferences  Non PreK
# 70455              NO_LABEL                    NO_LABEL  NO_LABEL
# 203453             NO_LABEL                    NO_LABEL  NO_LABEL
# 58170            Substitute     Substitute Compensation  Non PreK
# 72072        Vice Principal    Base Salary/Compensation  Non PreK
# 68311               Teacher  Other Compensation/Stipend  NO_LABEL
# 225892              Teacher    Base Salary/Compensation  NO_LABEL
# 446383             NO_LABEL                    NO_LABEL  NO_LABEL
# 155111                Other  Other Compensation/Stipend  Non PreK
# 278248             NO_LABEL          Supplies/Materials  NO_LABEL
# 397424             NO_LABEL                    NO_LABEL  NO_LABEL
# 375092           Substitute     Substitute Compensation  Non PreK
# 220181                Other    Base Salary/Compensation  Non PreK
# 307423             NO_LABEL                    NO_LABEL  NO_LABEL
# 46691               Teacher  Other Compensation/Stipend  NO_LABEL
# 109283  Instructional Coach  Other Compensation/Stipend  NO_LABEL
# 102430           Substitute    Base Salary/Compensation  NO_LABEL
# 413949                Other                    NO_LABEL  NO_LABEL
# 433672            Librarian                    Benefits  NO_LABEL
# 415831           Substitute     Substitute Compensation  Non PreK
#
#               Operating_Status  \
# 134338       PreK-12 Operating
# 206341           Non-Operating
# 326408       PreK-12 Operating
# 364634       PreK-12 Operating
# 47683        PreK-12 Operating
# 229958       PreK-12 Operating
# 417668       PreK-12 Operating
# 126378       PreK-12 Operating
# 275539       PreK-12 Operating
# 85262        PreK-12 Operating
# 304569           Non-Operating
# 330504       PreK-12 Operating
# 84272        PreK-12 Operating
# 64760            Non-Operating
# 21870   Operating, Not PreK-12
# 18698        PreK-12 Operating
# 169454       PreK-12 Operating
# 169914       PreK-12 Operating
# 189701       PreK-12 Operating
# 43727            Non-Operating
# 5614             Non-Operating
# 291539       PreK-12 Operating
# 307038       PreK-12 Operating
# 27645   Operating, Not PreK-12
# 126388       PreK-12 Operating
# 14962        PreK-12 Operating
# 84040            Non-Operating
# 61639        PreK-12 Operating
# 266302       PreK-12 Operating
# 225768       PreK-12 Operating
# ...                        ...
# 333748       PreK-12 Operating
# 292626           Non-Operating
# 343458       PreK-12 Operating
# 128261       PreK-12 Operating
# 186318       PreK-12 Operating
# 210652       PreK-12 Operating
# 340354       PreK-12 Operating
# 435205       PreK-12 Operating
# 174827       PreK-12 Operating
# 277504       PreK-12 Operating
# 248062       PreK-12 Operating
# 70455   Operating, Not PreK-12
# 203453           Non-Operating
# 58170        PreK-12 Operating
# 72072        PreK-12 Operating
# 68311        PreK-12 Operating
# 225892       PreK-12 Operating
# 446383           Non-Operating
# 155111       PreK-12 Operating
# 278248       PreK-12 Operating
# 397424           Non-Operating
# 375092       PreK-12 Operating
# 220181       PreK-12 Operating
# 307423           Non-Operating
# 46691        PreK-12 Operating
# 109283       PreK-12 Operating
# 102430       PreK-12 Operating
# 413949       PreK-12 Operating
# 433672       PreK-12 Operating
# 415831       PreK-12 Operating
#
#                                        Object_Description  \
# 134338                                                NaN
# 206341                                CONTRACTOR SERVICES
# 326408                       Personal Services - Teachers
# 364634                                  EMPLOYEE BENEFITS
# 47683                        TEACHER COVERAGE FOR TEACHER
# 229958                                    CONTRA BENEFITS
# 417668                                        EDUCATIONAL
# 126378                                  EMPLOYEE BENEFITS
# 275539                                  EMPLOYEE BENEFITS
# 85262                                   EMPLOYEE BENEFITS
# 304569                                        EQUIPMENT *
# 330504                                           SUPPLIES
# 84272                        Personal Services - Teachers
# 64760                                           Regular *
# 21870                      OTHER PERSONAL SERVICES
# 18698     Salaries And Wages For Substitute Professionals
# 169454                     SUPPLIES
# 169914                                          Regular *
# 189701                                        ELECTRICITY
# 43727               Non-Certificated Travel Reimbursement
# 5614                                   Purchased Services
# 291539                     SALARIES OF PART TIME EMPLOYEE
# 307038                                          Regular *
# 27645                      BONUSES
# 126388  Personal Services - Substitute Teachers Certified
# 14962                        Personal Services - Teachers
# 84040                                         EQUIPMENT *
# 61639                                   EMPLOYEE BENEFITS
# 266302                                  EMPLOYEE BENEFITS
# 225768      Extra Duty Pay/Overtime For Support Personnel
# ...                                                   ...
# 333748                                          Regular *
# 292626      Extra Duty Pay/Overtime For Support Personnel
# 343458                     SALARIES OF PART TIME EMPLOYEE
# 128261                      SALARIES OF REGULAR EMPLOYEES
# 186318                      SALARIES OF REGULAR EMPLOYEES
# 210652  Personal Services - Substitute Teachers Non-Ce...
# 340354                                  EMPLOYEE BENEFITS
# 435205                       EMPLOYER PD MED CONTRIBUTION
# 174827                     SALARIES OF PART TIME EMPLOYEE
# 277504                                    CONTRA BENEFITS
# 248062             Travel And Subsistence - Employee Only
# 70455                      CLASSROOM TEACHER
# 203453                     IN-COUNTY TRAVEL
# 58170   Personal Services - Substitute Teachers Certified
# 72072            Personal Services - Assistant Principals
# 68311                      ADDITIONAL/EXTRA DUTY PAY/STIP
# 225892                      SALARIES OF REGULAR EMPLOYEES
# 446383                Other Pupil Transportation Services
# 155111      Extra Duty Pay/Overtime For Support Personnel
# 278248                                           SUPPLIES
# 397424                     ADDITIONAL/EXTRA DUTY PAY/STIP
# 375092  Personal Services - Substitute Teachers Certified
# 220181            Salaries Or Wages For Support Personnel
# 307423                            Other Awards and Prizes
# 46691                      ADDITIONAL/EXTRA DUTY PAY/STIP
# 109283                     WORKSHOP PARTICIPANT
# 102430                     SALARIES OF PART TIME EMPLOYEE
# 413949                                                NaN
# 433672                                  EMPLOYEE BENEFITS
# 415831    Salaries And Wages For Substitute Professionals
#
#                           ...                     \
# 134338                    ...
# 206341                    ...
# 326408                    ...
# 364634                    ...
# 47683                     ...
# 229958                    ...
# 417668                    ...
# 126378                    ...
# 275539                    ...
# 85262                     ...
# 304569                    ...
# 330504                    ...
# 84272                     ...
# 64760                     ...
# 21870                     ...
# 18698                     ...
# 169454                    ...
# 169914                    ...
# 189701                    ...
# 43727                     ...
# 5614                      ...
# 291539                    ...
# 307038                    ...
# 27645                     ...
# 126388                    ...
# 14962                     ...
# 84040                     ...
# 61639                     ...
# 266302                    ...
# 225768                    ...
# ...                       ...
# 333748                    ...
# 292626                    ...
# 343458                    ...
# 128261                    ...
# 186318                    ...
# 210652                    ...
# 340354                    ...
# 435205                    ...
# 174827                    ...
# 277504                    ...
# 248062                    ...
# 70455                     ...
# 203453                    ...
# 58170                     ...
# 72072                     ...
# 68311                     ...
# 225892                    ...
# 446383                    ...
# 155111                    ...
# 278248                    ...
# 397424                    ...
# 375092                    ...
# 220181                    ...
# 307423                    ...
# 46691                     ...
# 109283                    ...
# 102430                    ...
# 413949                    ...
# 433672                    ...
# 415831                    ...
#
#                                Sub_Object_Description  \
# 134338                                            NaN
# 206341                                            NaN
# 326408                                            NaN
# 364634                                            NaN
# 47683                                             NaN
# 229958                                            NaN
# 417668                                            NaN
# 126378                                            NaN
# 275539                                            NaN
# 85262                                             NaN
# 304569                                    Equipment *
# 330504                                            NaN
# 84272                                             NaN
# 64760       Certificated Employees Salaries And Wages
# 21870                                             NaN
# 18698      Salaries And Wages For Substitute Teachers
# 169454                                            NaN
# 169914                                            NaN
# 189701                                            NaN
# 43727                Travel Mileage/Meeting Expense *
# 5614                               Purchased Services
# 291539                                            NaN
# 307038      Certificated Employees Salaries And Wages
# 27645                                             NaN
# 126388                                            NaN
# 14962                                             NaN
# 84040                                     Equipment *
# 61639                                             NaN
# 266302                                            NaN
# 225768  Extra Duty Pay/Overtime For Support Personnel
# ...                                               ...
# 333748      Certificated Employees Salaries And Wages
# 292626  Extra Duty Pay/Overtime For Support Personnel
# 343458                                            NaN
# 128261                                            NaN
# 186318                                            NaN
# 210652                                            NaN
# 340354                                            NaN
# 435205                                            NaN
# 174827                                            NaN
# 277504                                            NaN
# 248062         Travel And Subsistence - Employee Only
# 70455                                             NaN
# 203453                                            NaN
# 58170                                             NaN
# 72072                                             NaN
# 68311                                             NaN
# 225892                                            NaN
# 446383                         Pupil Transportation *
# 155111  Extra Duty Pay/Overtime For Support Personnel
# 278248                                            NaN
# 397424                                            NaN
# 375092                                            NaN
# 220181        Salaries Or Wages For Support Personnel
# 307423                            Awards And Prizes *
# 46691                                             NaN
# 109283                                            NaN
# 102430                                            NaN
# 413949                                            NaN
# 433672                                            NaN
# 415831     Inservice Substitute Teachers Grant Funded
#
#                   Location_Description       FTE  \
# 134338                             NaN  1.000000
# 206341                             NaN       NaN
# 326408                             NaN  1.000000
# 364634                             NaN       NaN
# 47683                              NaN       NaN
# 229958                             NaN       NaN
# 417668                             NaN       NaN
# 126378  DISTRICT WIDE ORGANIZATION UNI       NaN
# 275539                             NaN       NaN
# 85262                              NaN       NaN
# 304569                             NaN       NaN
# 330504                             NaN       NaN
# 84272                              NaN  0.600000
# 64760                              NaN       NaN
# 21870                          CHARTER  0.000000
# 18698                          School        NaN
# 169454                         School        NaN
# 169914    SAFETY AND SECURITY DIVISION  1.000000
# 189701                             NaN       NaN
# 43727                              NaN       NaN
# 5614                               NaN       NaN
# 291539                             NaN  0.012931
# 307038      SR OTH CERTIFICATED PERSON  1.000000
# 27645                          CHARTER       NaN
# 126388                             NaN  0.000000
# 14962                              NaN  1.000000
# 84040                              NaN       NaN
# 61639                              NaN       NaN
# 266302                             NaN       NaN
# 225768                   Undistributed       NaN
# ...                                ...       ...
# 333748      PSYCHOLOGICAL SERVICES OFF  1.000000
# 292626                     Unallocated       NaN
# 343458       ALL SCHOOLS-UNDISTRIBUTED       NaN
# 128261                             NaN       NaN
# 186318                             NaN  1.000025
# 210652                             NaN  0.000000
# 340354                             NaN       NaN
# 435205                             NaN       NaN
# 174827                             NaN       NaN
# 277504                             NaN       NaN
# 248062                         School        NaN
# 70455                          School   1.000000
# 203453                         School        NaN
# 58170                              NaN  0.000000
# 72072                              NaN  1.000000
# 68311                   MATH / SCIENCE       NaN
# 225892                             NaN       NaN
# 446383                             NaN       NaN
# 155111                     Unallocated       NaN
# 278248                             NaN       NaN
# 397424                             NaN       NaN
# 375092                             NaN  0.000000
# 220181                         School   0.090000
# 307423                             NaN       NaN
# 46691                   MATH / SCIENCE       NaN
# 109283  STAFF DEV AND INSTR MEDIA            NaN
# 102430                             NaN  0.004310
# 413949                             NaN  1.000000
# 433672            ED RESOURCE SERVICES       NaN
# 415831                         School        NaN
#
#                                      Function_Description  \
# 134338                                                NaN
# 206341                                           RGN  GOB
# 326408                                                NaN
# 364634                            UNALLOC BUDGETS/SCHOOLS
# 47683                                         NON-PROJECT
# 229958                                        NON-PROJECT
# 417668                                                NaN
# 126378                                        NON-PROJECT
# 275539                      ELA S - TEACHING SPANISH ONLY
# 85262                             UNALLOC BUDGETS/SCHOOLS
# 304569  State and Federal Projects Coordination Services*
# 330504                                        INSTRUCTION
# 84272                                                 NaN
# 64760                               Disadvantaged Youth *
# 21870                      BASIC (FEFP K-12)
# 18698                                         Instruction
# 169454                     BASIC (FEFP K-12)
# 169914                                  Security Services
# 189701                                        NON-PROJECT
# 43727   Instruction And Curriculum Development Services *
# 5614             Direction Of Support Services - Pupils *
# 291539                            UNALLOC BUDGETS/SCHOOLS
# 307038                              Disadvantaged Youth *
# 27645                      GUIDANCE SERVICES
# 126388                                                NaN
# 14962                                                 NaN
# 84040   Instruction And Curriculum Development Services *
# 61639                                        CORE MATTERS
# 266302                       ELA E-TEACHING SHELTERED ENG
# 225768                                     Transportation
# ...                                                   ...
# 333748                           Psychological Services *
# 292626            Facilities Acquisition And Construction
# 343458                            UNALLOC BUDGETS/SCHOOLS
# 128261                         SPECIAL ED. - SEVERE NEEDS
# 186318                      ELA S - TEACHING SPANISH ONLY
# 210652                                                NaN
# 340354                                     TITLE III  ELA
# 435205                        READ TO ACHIEVE ROUND THREE
# 174827                                            TITLE I
# 277504                                        NON-PROJECT
# 248062  Curriculum Development And Instructional Staff...
# 70455                      BASIC (FEFP K-12)
# 203453                     STAFF SERVICES
# 58170                                                 NaN
# 72072                                                 NaN
# 68311                      TITLE II-PART A-TEACHER QUALIT
# 225892                       ELA E-TEACHING SHELTERED ENG
# 446383  Instruction And Curriculum Development Services *
# 155111                                     Transportation
# 278248                                        INSTRUCTION
# 397424                                            NS  GOB
# 375092                                                NaN
# 220181          Food Services (Child Nutrition Fund Only)
# 307423       Other Improvements Of Instruction Services *
# 46691                      TITLE II-PART A-TEACHER QUALIT
# 109283                     INST STAFF TRAINING SVCS
# 102430                                         TITLE II,D
# 413949                                                NaN
# 433672                                        NON-PROJECT
# 415831                                        Instruction
#
#                             Facility_or_Department  \
# 134338                                         NaN
# 206341                                         NaN
# 326408                                         NaN
# 364634                                         NaN
# 47683                                          NaN
# 229958                                         NaN
# 417668                                         NaN
# 126378                                         NaN
# 275539                                         NaN
# 85262                                          NaN
# 304569                                         NaN
# 330504                                         NaN
# 84272                       POSITION CONTROL POOLS
# 64760                                          NaN
# 21870                                          NaN
# 18698                           All Campus Payroll
# 169454                                         NaN
# 169914                                         NaN
# 189701                                         NaN
# 43727                                          NaN
# 5614                                           NaN
# 291539                                         NaN
# 307038                                         NaN
# 27645                                          NaN
# 126388                                         NaN
# 14962                                          NaN
# 84040                                          NaN
# 61639                                          NaN
# 266302                                         NaN
# 225768                   Transportation Department
# ...                                            ...
# 333748                                         NaN
# 292626  New Construction Department Administration
# 343458                                         NaN
# 128261                                         NaN
# 186318                                         NaN
# 210652                              TEACHER SUPPLY
# 340354                                         NaN
# 435205                                         NaN
# 174827                                         NaN
# 277504                                         NaN
# 248062                                  Vocational
# 70455                                          NaN
# 203453                                         NaN
# 58170                                          NaN
# 72072                                          NaN
# 68311                                          NaN
# 225892                                         NaN
# 446383                                         NaN
# 155111                   Transportation Department
# 278248                                         NaN
# 397424                                         NaN
# 375092                                         NaN
# 220181                             Child Nutrition
# 307423                                         NaN
# 46691                                          NaN
# 109283                                         NaN
# 102430                                         NaN
# 413949                                         NaN
# 433672                                         NaN
# 415831                  Instruction And Curriculum
#
#                        Position_Extra          Total  \
# 134338                  KINDERGARTEN    50471.810000
# 206341                   UNDESIGNATED    3477.860000
# 326408                        TEACHER   62237.130000
# 364634     PROFESSIONAL-INSTRUCTIONAL      22.300000
# 47683      PROFESSIONAL-INSTRUCTIONAL      54.166000
# 229958                   UNDESIGNATED      -8.150000
# 417668         SUPPLIES AND MATERIALS    2000.050000
# 126378                   UNDESIGNATED       0.720000
# 275539     PROFESSIONAL-INSTRUCTIONAL     228.250000
# 85262      PROFESSIONAL-INSTRUCTIONAL      69.560000
# 304569                            NaN   -5509.320000
# 330504                            NaN      16.410000
# 84272                         TEACHER   38824.790000
# 64760                             NaN -122544.070000
# 21870                             NaN     228.530000
# 18698              DEGREED SUBSTITUTE      94.357986
# 169454                            NaN     146.510000
# 169914                            NaN   66651.255981
# 189701                   UNDESIGNATED   30382.320000
# 43727                             NaN    -446.110000
# 5614                              NaN     550.310000
# 291539     PROFESSIONAL-INSTRUCTIONAL     329.353815
# 307038                            NaN  103318.698037
# 27645                             NaN     649.860000
# 126388             SUBSTITUTE TEACHER      71.140000
# 14962                 TEACHER -  DAYS   17101.770000
# 84040                             NaN  -21795.930000
# 61639      PROFESSIONAL-INSTRUCTIONAL       1.120000
# 266302     PROFESSIONAL-INSTRUCTIONAL    5037.240000
# 225768                     BUS DRIVER     201.680000
# ...                               ...            ...
# 333748                            NaN  108879.445586
# 292626         DIR EXEC DIR SECRETARY      34.720000
# 343458     PROFESSIONAL-INSTRUCTIONAL     107.459600
# 128261     PROFESSIONAL-INSTRUCTIONAL    2191.170000
# 186318     PROFESSIONAL-INSTRUCTIONAL   48618.855433
# 210652             SUBSTITUTE TEACHER     111.960000
# 340354               PARAPROFESSIONAL     791.520000
# 435205     PROFESSIONAL-INSTRUCTIONAL     503.490000
# 174827               PARAPROFESSIONAL      37.824320
# 277504                   UNDESIGNATED    -838.820000
# 248062                            NaN    1830.860000
# 70455                             NaN   71846.661087
# 203453                            NaN      28.000000
# 58170              SUBSTITUTE TEACHER      71.310000
# 72072                  ASST PRINCIPAL   65258.960000
# 68311      PROFESSIONAL-INSTRUCTIONAL     142.124320
# 225892     PROFESSIONAL-INSTRUCTIONAL    2834.496320
# 446383                            NaN   -7725.350000
# 155111     RADIO & SUBSTITUTE DRIVERS     759.340000
# 278248                            NaN      74.590000
# 397424               PARAPROFESSIONAL     157.654000
# 375092             SUBSTITUTE TEACHER     141.939900
# 220181       REG FOOD SERVICE WORKER     2293.931767
# 307423                            NaN    -390.710000
# 46691      PROFESSIONAL-INSTRUCTIONAL     283.988640
# 109283                            NaN      48.620000
# 102430     PROFESSIONAL-INSTRUCTIONAL     128.824985
# 413949                 PARENT/TITLE I    4902.290000
# 433672  OFFICE/ADMINISTRATIVE SUPPORT    4020.290000
# 415831           CERTIFIED SUBSTITUTE      46.530000
#
#                                       Program_Description  \
# 134338                                       KINDERGARTEN
# 206341                      BUILDING IMPROVEMENT SERVICES
# 326408                              Instruction - Regular
# 364634                     GENERAL MIDDLE/JUNIOR HIGH SCH
# 47683                       GENERAL HIGH SCHOOL EDUCATION
# 229958                                  EMPLOYEE BENEFITS
# 417668                            SPECIAL EDUCATION LOCAL
# 126378                                       UNDESIGNATED
# 275539                       GENERAL ELEMENTARY EDUCATION
# 85262                        GENERAL ELEMENTARY EDUCATION
# 304569                                                NaN
# 330504                            PRIMARY GRADES PROGRAM
# 84272                               Instruction - Regular
# 64760                                                 NaN
# 21870                                                 NaN
# 18698   Bilingual Education And Special Language Programs
# 169454                                                NaN
# 169914                                                NaN
# 189701                     CARE & UPKEEP OF BLDG SERVICES
# 43727                                                 NaN
# 5614                                                  NaN
# 291539                       GENERAL ELEMENTARY EDUCATION
# 307038                                                NaN
# 27645                                                 NaN
# 126388                              Instruction - Regular
# 14962                               Instruction - Regular
# 84040                                                 NaN
# 61639                        INSTRUCTIONAL STAFF TRAINING
# 266302                       GENERAL ELEMENTARY EDUCATION
# 225768                                      Undistributed
# ...                                                   ...
# 333748                                                NaN
# 292626                                      Undistributed
# 343458                            OTHER GENERAL EDUCATION
# 128261                         SPECIAL EDUCATION-TMD HIGH
# 186318                       GENERAL ELEMENTARY EDUCATION
# 210652                                 Instruction - SPED
# 340354                      GENERAL HIGH SCHOOL EDUCATION
# 435205                       GENERAL ELEMENTARY EDUCATION
# 174827                       GENERAL ELEMENTARY EDUCATION
# 277504                                  EMPLOYEE BENEFITS
# 248062                              Career And Technology
# 70455                                                 NaN
# 203453                                                NaN
# 58170                       Support - Regular Instruction
# 72072                                  Principal's Office
# 68311                        INSTRUCTIONAL STAFF TRAINING
# 225892                       GENERAL ELEMENTARY EDUCATION
# 446383                                                NaN
# 155111                                      Undistributed
# 278248                            PRIMARY GRADES PROGRAM
# 397424                     GENERAL MIDDLE/JUNIOR HIGH SCH
# 375092                              Instruction - Regular
# 220181                                      Undistributed
# 307423                                                NaN
# 46691                        INSTRUCTIONAL STAFF TRAINING
# 109283                                                NaN
# 102430                       INSTRUCTIONAL STAFF TRAINING
# 413949                                               Misc
# 433672                             MEDIA SUPPORT SERVICES
# 415831                              Accelerated Education
#
#                                          Fund_Description  \
# 134338                                       General Fund
# 206341                                                NaN
# 326408                             General Purpose School
# 364634                                                NaN
# 47683                                                 NaN
# 229958                                                NaN
# 417668                                         LOCAL FUND
# 126378                                                NaN
# 275539                                                NaN
# 85262                                                 NaN
# 304569                                     School to Work
# 330504                                       General Fund
# 84272                              General Purpose School
# 64760   Title I - Disadvantaged Children/Targeted Assi...
# 21870                      CONVERSION CHARTER SCHOOLS
# 18698                              General Operating Fund
# 169454                     GENERAL FUND
# 169914                                            General
# 189701                                                NaN
# 43727                                       Special Trust
# 5614                                        Special Trust
# 291539                                                NaN
# 307038  Title I - Disadvantaged Children/Targeted Assi...
# 27645                      CONVERSION CHARTER SCHOOLS
# 126388                             General Purpose School
# 14962                             School Federal Projects
# 84040                                       Special Trust
# 61639                                                 NaN
# 266302                                                NaN
# 225768                             General Operating Fund
# ...                                                   ...
# 333748                                            General
# 292626                             General Operating Fund
# 343458                                                NaN
# 128261                                                NaN
# 186318                                                NaN
# 210652                            School Federal Projects
# 340354                                                NaN
# 435205                                                NaN
# 174827                                                NaN
# 277504                                                NaN
# 248062                             General Operating Fund
# 70455                      CONVERSION CHARTER SCHOOLS
# 203453                     EXTENDED LEARNING CENTER ELC
# 58170                             School Federal Projects
# 72072                              General Purpose School
# 68311                                                 NaN
# 225892                                                NaN
# 446383                                      Special Trust
# 155111                             General Operating Fund
# 278248                                       General Fund
# 397424                                                NaN
# 375092                             General Purpose School
# 220181        National School Breakfast And Lunch Program
# 307423                         Miscellaneous State Grants
# 46691                                                 NaN
# 109283                     GENERAL FUND
# 102430                                                NaN
# 413949                                 Schoolwide Schools
# 433672                                                NaN
# 415831           "Title  Part A Improving Basic Programs"
#
#                                           Text_1
# 134338                                       NaN
# 206341             BUILDING IMPROVEMENT SERVICES
# 326408                                       NaN
# 364634                       REGULAR INSTRUCTION
# 47683                        REGULAR INSTRUCTION
# 229958                         EMPLOYEE BENEFITS
# 417668                                       NaN
# 126378                              UNDESIGNATED
# 275539                       REGULAR INSTRUCTION
# 85262                        REGULAR INSTRUCTION
# 304569                ITEMAI-CITY-YTH EMP & OPP
# 330504                                       NaN
# 84272                                        NaN
# 64760                                   TITLE I
# 21870                                        NaN
# 18698                                REGULAR PAY
# 169454            TEACHER LEAD
# 169914                         SAFETY & SECURITY
# 189701              OPERATION AND MAINT OF PLANT
# 43727                      RESP SEXUAL BEHAVIOR
# 5614                        HOME TEAM MARKETING
# 291539                       REGULAR INSTRUCTION
# 307038                      BUILDING ALLOCATIONS
# 27645                                        NaN
# 126388                                       NaN
# 14962                 ESEA TITLE I DISADVANTAGED
# 84040                  KEY BANK NATIONAL ASSOCIA
# 61639                        INSTRUCTIONAL STAFF
# 266302                       REGULAR INSTRUCTION
# 225768             ADDL REGULAR PAY-NOT SMOOTHED
# ...                                          ...
# 333748                    PSYCHOLOGICAL SERVICES
# 292626                                  OVERTIME
# 343458                       REGULAR INSTRUCTION
# 128261                         SPECIAL EDUCATION
# 186318                       REGULAR INSTRUCTION
# 210652  INDIVIDUALS WITH DISABILITIES ACT PART B
# 340354                       REGULAR INSTRUCTION
# 435205                       REGULAR INSTRUCTION
# 174827                       REGULAR INSTRUCTION
# 277504                         EMPLOYEE BENEFITS
# 248062                                       NaN
# 70455                                        NaN
# 203453                                       NaN
# 58170                                      OTHER
# 72072                                        NaN
# 68311                        INSTRUCTIONAL STAFF
# 225892                       REGULAR INSTRUCTION
# 446383                    ITEMS FOUNDATION-JUNE
# 155111                                  OVERTIME
# 278248                                       NaN
# 397424                       REGULAR INSTRUCTION
# 375092                                       NaN
# 220181                               REGULAR PAY
# 307423                  SCHOOL IMPROV INCENTIVES
# 46691                        INSTRUCTIONAL STAFF
# 109283            STAFF DEV AND INSTR MEDIA
# 102430                       INSTRUCTIONAL STAFF
# 413949                                       NaN
# 433672                       INSTRUCTIONAL STAFF
# 415831                            MISCELLANEOUS
#
# [400277 rows x 25 columns]

# %% [markdown]
# ## N-gram range in scikit-learn

# %% [markdown]
# Now we'll insert a CountVectorizer instance into our pipeline for the main dataset, and compute multiple n-gram features to be used in the model.
#
# In order to look for ngram relationships at multiple scales, we will use the ngram_range parameter.
#
# Special functions: We'll notice a couple of new steps provided in the pipeline in this and many of the remaining exercises. Specifically, the dim_red step following the vectorizer step , and the scale step preceeding the clf (classification) step.
#
# These have been added in order to account for the fact that we're using a reduced-size sample of the full dataset. To make sure the models perform as the expert competition winner intended, we have to apply a dimensionality reduction technique, which is what the dim_red step does, and we have to scale the features to lie between -1 and 1, which is what the scale step does.
#
# The dim_red step uses a scikit-learn function called SelectKBest(), applying something called the chi-squared test to select the K "best" features. The scale step uses a scikit-learn function called MaxAbsScaler() in order to squash the relevant features into the interval -1 to 1.
#
# We won't need to do anything extra with these functions here, just complete the vectorizing pipeline steps below.

# %%
# Import pipeline
from sklearn.pipeline import Pipeline

# Import classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier

# Import CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# Import other preprocessing modules
from sklearn.preprocessing import Imputer
from sklearn.feature_selection import chi2, SelectKBest

# Select 300 best features
chi_k = 300

# Import functional utilities
from sklearn.preprocessing import FunctionTransformer, MaxAbsScaler
from sklearn.pipeline import FeatureUnion

# Perform preprocessing
get_text_data = FunctionTransformer(combine_text_columns, validate=False)
get_numeric_data = FunctionTransformer(lambda x: x[NUMERIC_COLUMNS], validate=False)

# Create the token pattern: TOKENS_ALPHANUMERIC
TOKENS_ALPHANUMERIC = '[A-Za-z0-9]+(?=\\s+)'

# Instantiate pipeline: pl
pl = Pipeline([
        ('union', FeatureUnion(
            transformer_list = [
                ('numeric_features', Pipeline([
                    ('selector', get_numeric_data),
                    ('imputer', Imputer())
                ])),
                ('text_features', Pipeline([
                    ('selector', get_text_data),
                    ('vectorizer',CountVectorizer(token_pattern=TOKENS_ALPHANUMERIC,
                                                   ngram_range=(1,2))),
                    ('dim_red', SelectKBest(chi2, chi_k))
                ]))
             ]
        )),
        ('scale', MaxAbsScaler()),
        ('clf', OneVsRestClassifier(LogisticRegression()))
    ])
# Fit to the training data
pl.fit(X_train, y_train)

# Compute and print accuracy
accuracy = pl.score(X_test, y_test)
print("\nAccuracy on budget dataset: ", accuracy)

# %% [markdown]
# ## Interaction modeling in scikit-learn

# %% [markdown]
# It's time to add interaction features to your model. The PolynomialFeatures object in scikit-learn does just that, but here we're going to a custom interaction object, SparseInteractions.
#
# Interaction terms are a statistical tool that lets our model express what happens if two features appear together in the same row.
# SparseInteractions does the same thing as PolynomialFeatures, but it uses sparse matrices to do so.
#
# PolynomialFeatures and SparseInteractions both take the argument degree, which tells them what polynomia degree of interactions to compute.
#
# We're going to consider interaction terms of degree=2 in our pipeline.. We will insert these steps after the preprocessing steps we've built out so far, but before the classifier steps.
#
# Pipelines with interaction terms take a while to train (since we're making n features into n-squared features!), so as long as we set it up right, we'll do the heavy lifting and tell  what our score is!

# %%
from itertools import combinations

import numpy as np
from scipy import sparse
from sklearn.base import BaseEstimator, TransformerMixin


class SparseInteractions(BaseEstimator, TransformerMixin):
    def __init__(self, degree=2, feature_name_separator="_"):
        self.degree = degree
        self.feature_name_separator = feature_name_separator

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        if not sparse.isspmatrix_csc(X):
            X = sparse.csc_matrix(X)

        if hasattr(X, "columns"):
            self.orig_col_names = X.columns
        else:
            self.orig_col_names = np.array([str(i) for i in range(X.shape[1])])

        spi = self._create_sparse_interactions(X)
        return spi

    def get_feature_names(self):
        return self.feature_names

    def _create_sparse_interactions(self, X):
        out_mat = []
        self.feature_names = self.orig_col_names.tolist()

        for sub_degree in range(2, self.degree + 1):
            for col_ixs in combinations(range(X.shape[1]), sub_degree):
                # add name for new column
                name = self.feature_name_separator.join(self.orig_col_names[list(col_ixs)])
                self.feature_names.append(name)

                # get column multiplications value
                out = X[:, col_ixs[0]]
                for j in col_ixs[1:]:
                    out = out.multiply(X[:, j])

                out_mat.append(out)

        return sparse.hstack([X] + out_mat)

# %%
# Instantiate pipeline: pl
pl = Pipeline([
        ('union', FeatureUnion(
            transformer_list = [
                ('numeric_features', Pipeline([
                    ('selector', get_numeric_data),
                    ('imputer', Imputer())
                ])),
                ('text_features', Pipeline([
                    ('selector', get_text_data),
                    ('vectorizer', CountVectorizer(token_pattern=TOKENS_ALPHANUMERIC,
                                                   ngram_range=(1, 2))),  
                    ('dim_red', SelectKBest(chi2, chi_k))
                ]))
             ]
        )),
        ('int',SparseInteractions(degree=2)),
        ('scale', MaxAbsScaler()),
        ('clf', OneVsRestClassifier(LogisticRegression()))
    ])
# Fit to the training data
pl.fit(X_train, y_train)

# Compute and print accuracy
accuracy = pl.score(X_test, y_test)
print("\nAccuracy on budget dataset: ", accuracy)

# %% [markdown]
# ## Hashing

# %% [markdown]
# Hash function takes an input, in our case a token, and outputs a hash value. For example, the input may be a string and the hash value may be an integer.
#
# Some problems are memory-bound and not easily parallelizable, and hashing enforces a fixed length computation instead of using a mutable datatype (like a dictionary).
#
# By explicitly stating how many possible outputs the hashing function may have, we limit the size of the objects that need to be processed. With these limits known, computation can be made more efficient and we can get results faster, even on large datasets.
#
#
# HashingVectorizer acts just like CountVectorizer in that it can accept token_pattern and ngram_range parameters. The important difference is that it creates hash values from the text, so that we get all the computational advantages of hashing!

# %%
# Import HashingVectorizer
from sklearn.feature_extraction.text import HashingVectorizer

# Get text data: text_data
text_data = combine_text_columns(X_train)

# Create the token pattern: TOKENS_ALPHANUMERIC
TOKENS_ALPHANUMERIC = '[A-Za-z0-9]+(?=\\s+)' 

# Instantiate the HashingVectorizer: hashing_vec
hashing_vec =HashingVectorizer(token_pattern=TOKENS_ALPHANUMERIC)

# Fit and transform the Hashing Vectorizer
hashed_text =hashing_vec.fit_transform(text_data)

# Create DataFrame and print the head
hashed_df = pd.DataFrame(hashed_text.data)
print(hashed_df.head())
# Out:
# The Initial To_Drop contains
# ---------------------------------
#
#
# ['FTE', 'Total', 'Function', 'Use', 'Sharing', 'Reporting', 'Student_Type', 'Position_Type', 'Object_Type', 'Pre_K', 'Operating_Status']
#
#
#
#
# The Initial Columns of the DataFrame are:
# ----------------------------------------
#
#
# ['Object_Description', 'Text_2', 'SubFund_Description', 'Job_Title_Description', 'Text_3', 'Text_4', 'Sub_Object_Description', 'Location_Description', 'FTE', 'Function_Description', 'Facility_or_Department', 'Position_Extra', 'Total', 'Program_Description', 'Fund_Description', 'Text_1']
#
#
#
#
# The Final To_Drop Contains :
# ---------------------------------
#
#
# {'Total', 'FTE'}
#
#
#  THE SHAPE OF TEXT DATA
# --------------------
#
#
# (320222, 14)
#
#
# THE TEXT DATA IS:
# --------------------
#
#
#                                        Object_Description  \
# 134338                                                NaN
# 326408                       Personal Services - Teachers
# 364634                                  EMPLOYEE BENEFITS
# 47683                        TEACHER COVERAGE FOR TEACHER
# 229958                                    CONTRA BENEFITS
# 417668                                        EDUCATIONAL
# 126378                                  EMPLOYEE BENEFITS
# 85262                                   EMPLOYEE BENEFITS
# 304569                                        EQUIPMENT *
# 84272                        Personal Services - Teachers
# 64760                                           Regular *
# 21870                      OTHER PERSONAL SERVICES
# 169454                     SUPPLIES
# 169914                                          Regular *
# 189701                                        ELECTRICITY
# 43727               Non-Certificated Travel Reimbursement
# 5614                                   Purchased Services
# 307038                                          Regular *
# 27645                      BONUSES
# 126388  Personal Services - Substitute Teachers Certified
# 14962                        Personal Services - Teachers
# 84040                                         EQUIPMENT *
# 61639                                   EMPLOYEE BENEFITS
# 266302                                  EMPLOYEE BENEFITS
# 225768      Extra Duty Pay/Overtime For Support Personnel
# 267322                                    CONTRA BENEFITS
# 308098      Extra Duty Pay/Overtime For Support Personnel
# 227367                                 Purchased Services
# 329096                      SALARIES OF REGULAR EMPLOYEES
# 282308                     OTHER SUPPORT PERSONNEL
# ...                                                   ...
# 209265                                                NaN
# 333748                                          Regular *
# 292626      Extra Duty Pay/Overtime For Support Personnel
# 343458                     SALARIES OF PART TIME EMPLOYEE
# 128261                      SALARIES OF REGULAR EMPLOYEES
# 186318                      SALARIES OF REGULAR EMPLOYEES
# 210652  Personal Services - Substitute Teachers Non-Ce...
# 340354                                  EMPLOYEE BENEFITS
# 435205                       EMPLOYER PD MED CONTRIBUTION
# 174827                     SALARIES OF PART TIME EMPLOYEE
# 277504                                    CONTRA BENEFITS
# 248062             Travel And Subsistence - Employee Only
# 70455                      CLASSROOM TEACHER
# 203453                     IN-COUNTY TRAVEL
# 58170   Personal Services - Substitute Teachers Certified
# 68311                      ADDITIONAL/EXTRA DUTY PAY/STIP
# 225892                      SALARIES OF REGULAR EMPLOYEES
# 446383                Other Pupil Transportation Services
# 155111      Extra Duty Pay/Overtime For Support Personnel
# 278248                                           SUPPLIES
# 397424                     ADDITIONAL/EXTRA DUTY PAY/STIP
# 375092  Personal Services - Substitute Teachers Certified
# 220181            Salaries Or Wages For Support Personnel
# 307423                            Other Awards and Prizes
# 46691                      ADDITIONAL/EXTRA DUTY PAY/STIP
# 109283                     WORKSHOP PARTICIPANT
# 102430                     SALARIES OF PART TIME EMPLOYEE
# 413949                                                NaN
# 433672                                  EMPLOYEE BENEFITS
# 415831    Salaries And Wages For Substitute Professionals
#
#                                Text_2  \
# 134338                            NaN
# 326408                            NaN
# 364634                   TEACHER SUBS
# 47683                    TEACHER SUBS
# 229958                            NaN
# 417668  SPECIAL EDUCATION INSTRUCTION
# 126378                            NaN
# 85262                    TEACHER SUBS
# 304569                            NaN
# 84272                             NaN
# 64760                             NaN
# 21870                             NaN
# 169454                            NaN
# 169914                       ADM/PROF
# 189701         OPERATIONS - UTILITIES
# 43727                             NaN
# 5614                              NaN
# 307038                        TEACHER
# 27645                             NaN
# 126388                            NaN
# 14962                             NaN
# 84040                             NaN
# 61639                             NaN
# 266302                            NaN
# 225768                            NaN
# 267322                            NaN
# 308098                            NaN
# 227367                            NaN
# 329096                  FOOD SERVICES
# 282308                            NaN
# ...                               ...
# 209265                            NaN
# 333748                     TEACHERSUP
# 292626                            NaN
# 343458                   TEACHER SUBS
# 128261            SEVERE DISABILITIES
# 186318                            NaN
# 210652                            NaN
# 340354                            NaN
# 435205                            NaN
# 174827                            NaN
# 277504                            NaN
# 248062                            NaN
# 70455                             NaN
# 203453                            NaN
# 58170                             NaN
# 68311                    MATH/SCIENCE
# 225892                            NaN
# 446383                            NaN
# 155111                            NaN
# 278248                            NaN
# 397424                            NaN
# 375092                            NaN
# 220181                            NaN
# 307423                            NaN
# 46691                    MATH/SCIENCE
# 109283                            NaN
# 102430                            NaN
# 413949                            NaN
# 433672  EDUCATIONAL RESOURCE SERVICES
# 415831                            NaN
#
#                                 SubFund_Description  \
# 134338                                          NaN
# 326408                                          NaN
# 364634                                 GENERAL FUND
# 47683                                  GENERAL FUND
# 229958                                 GENERAL FUND
# 417668                                        LOCAL
# 126378                                 GENERAL FUND
# 85262                                  GENERAL FUND
# 304569            Support Services - Administration
# 84272                                           NaN
# 64760                           Special Instruction
# 21870                                           NaN
# 169454                                          NaN
# 169914  Operation and Maintenance of Plant Services
# 189701                                 GENERAL FUND
# 43727        Support Services - Instructional Staff
# 5614                       Support Services--Pupils
# 307038                          Special Instruction
# 27645                                           NaN
# 126388                                          NaN
# 14962                                           NaN
# 84040        Support Services - Instructional Staff
# 61639                                  GENERAL FUND
# 266302                                 GENERAL FUND
# 225768                                   Operations
# 267322                                 GENERAL FUND
# 308098                                   Operations
# 227367                           Community Services
# 329096                            FOOD SERVICE FUND
# 282308                                          NaN
# ...                                             ...
# 209265                                          NaN
# 333748                     Support Services--Pupils
# 292626                                   Operations
# 343458                                 GENERAL FUND
# 128261                                 GENERAL FUND
# 186318                                 GENERAL FUND
# 210652                                          NaN
# 340354                      FEDERAL GDPG FUND - FY
# 435205                    STATE AND LOCAL GDPG FUND
# 174827                      FEDERAL GDPG FUND - FY
# 277504                                 GENERAL FUND
# 248062                                          NaN
# 70455                                           NaN
# 203453                                          NaN
# 58170                                           NaN
# 68311                       FEDERAL GDPG FUND - FY
# 225892                                 GENERAL FUND
# 446383       Support Services - Instructional Staff
# 155111                                   Operations
# 278248                      PRIMARY GRADES PROGRAM
# 397424                                         BOND
# 375092                                          NaN
# 220181                              Child Nutrition
# 307423       Support Services - Instructional Staff
# 46691                       FEDERAL GDPG FUND - FY
# 109283                                          NaN
# 102430                      FEDERAL GDPG FUND - FY
# 413949                                          NaN
# 433672                                LEVY OVERRIDE
# 415831     "Title  Part A Improving Basic Programs"
#
#                          Job_Title_Description       Text_3  \
# 134338                     Teacher-Elementary           NaN
# 326408                         TCHER 2ND GRADE          NaN
# 364634                Teacher, Short Term Sub       Regular
# 47683               Teacher, Secondary (High)   Alternative
# 229958                 Custodian - PT -  Jobs           n/a
# 417668                                     NaN          NaN
# 126378              Sub Manager, Food Service           n/a
# 85262             Teacher,Retrd Shrt Term Sub       Regular
# 304569                                     NaN          NaN
# 84272   TCHER P E (ELEM POSITION CONTROL POOL)          NaN
# 64760                                      NaN          NaN
# 21870           SUB TEACHER ALL                         NaN
# 169454          TEACHER, TITLE I-ELEM                   NaN
# 169914              ADMIN LIEUTENANT COMM SERV          NaN
# 189701                                 (blank)      Regular
# 43727                                      NaN          NaN
# 5614                                       NaN          NaN
# 307038                     TCHR, SCNDY ENGLISH          NaN
# 27645           ESE CLERICAL ASSISTANT II               NaN
# 126388                                     NaN          NaN
# 14962                TCHER ENGLISH (SECONDARY)          NaN
# 84040                                      NaN          NaN
# 61639                 Teacher, Short Term Sub       Regular
# 266302                    Teacher, Elementary       Regular
# 225768          TRANSPORTATION,BUS DRIVERS,REG          NaN
# 267322             Teacher,Spec Ed Center Prg           n/a
# 308098          TRANSPORTATION,BUS DRIVERS,REG          NaN
# 227367                                     NaN          NaN
# 329096               Manager, Food Service IV           n/a
# 282308          FOOD SERVICE ASSISTANT                  NaN
# ...                                        ...          ...
# 209265                   Teacher-Middle School          NaN
# 333748                            PSYCHOLOGIST          NaN
# 292626           CLERICAL, BLDG.& CONSTRUCTION          NaN
# 343458                 Teacher, Super Sub D/D           n/a
# 128261             Teacher,Spec Ed Center Prg       Regular
# 186318                    Teacher, Elementary       Regular
# 210652                                     NaN          NaN
# 340354                 ELA General Assignment       Regular
# 435205                    Teacher, Elementary       Regular
# 174827                 ELA General Assignment       Regular
# 277504                    Teacher, Elementary           n/a
# 248062                                     NaN          NaN
# 70455           TEACHER, SOC STUDIES-MIDDLE             NaN
# 203453                                     NaN          NaN
# 58170                                      NaN          NaN
# 68311                     Teacher, Elementary           n/a
# 225892                    Teacher, Elementary       Regular
# 446383                                     NaN          NaN
# 155111          TRANSPORTATION, SUBSTITUTE,REG          NaN
# 278248                                     NaN          NaN
# 397424                 Secondary Spec Ed Para    Turnaround
# 375092                                     NaN          NaN
# 220181          CAFETERIA EMPLOYEE, FOOD SERV.          NaN
# 307423                                     NaN          NaN
# 46691                     Teacher, Elementary           n/a
# 109283          CURRICULUM RESOURCE TEACHER             NaN
# 102430            Teacher,Retrd Shrt Term Sub       Regular
# 413949                          School Liaison          NaN
# 433672                  Library Technician II           n/a
# 415831                 TEACHER SUBSTITUTE POOL          NaN
#
#                                     Text_4  \
# 134338                                 NaN
# 326408                 Regular Instruction
# 364634                                 NaN
# 47683                                  NaN
# 229958                                 NaN
# 417668                                 NaN
# 126378                                 NaN
# 85262                                  NaN
# 304569                                 NaN
# 84272                  Regular Instruction
# 64760                                  NaN
# 21870                                  NaN
# 169454                                 NaN
# 169914                                 NaN
# 189701                                 NaN
# 43727                                  NaN
# 5614                                   NaN
# 307038                                 NaN
# 27645                                  NaN
# 126388                 Regular Instruction
# 14962                           SIG - ARRA
# 84040                                  NaN
# 61639                                  NaN
# 266302                                 NaN
# 225768        Transportation - Bus Drivers
# 267322                                 NaN
# 308098        Transportation - Bus Drivers
# 227367                                 NaN
# 329096                                 NaN
# 282308                                 NaN
# ...                                    ...
# 209265                                 NaN
# 333748                                 NaN
# 292626                                 NaN
# 343458                                 NaN
# 128261                                 NaN
# 186318                                 NaN
# 210652                       IDEA Part B
# 340354                                 NaN
# 435205                                 NaN
# 174827                                 NaN
# 277504                                 NaN
# 248062                                 NaN
# 70455                                  NaN
# 203453                                 NaN
# 58170                      State TIF Grant
# 68311                                  NaN
# 225892                                 NaN
# 446383                                 NaN
# 155111        transportation - Second Runs
# 278248                                 NaN
# 397424                                 NaN
# 375092                 Regular Instruction
# 220181                       Undistributed
# 307423                                 NaN
# 46691                                  NaN
# 109283                                 NaN
# 102430                                 NaN
# 413949                                 NaN
# 433672                                 NaN
# 415831  Multilingual Dist Prof Development
#
#                                Sub_Object_Description  \
# 134338                                            NaN
# 326408                                            NaN
# 364634                                            NaN
# 47683                                             NaN
# 229958                                            NaN
# 417668                                            NaN
# 126378                                            NaN
# 85262                                             NaN
# 304569                                    Equipment *
# 84272                                             NaN
# 64760       Certificated Employees Salaries And Wages
# 21870                                             NaN
# 169454                                            NaN
# 169914                                            NaN
# 189701                                            NaN
# 43727                Travel Mileage/Meeting Expense *
# 5614                               Purchased Services
# 307038      Certificated Employees Salaries And Wages
# 27645                                             NaN
# 126388                                            NaN
# 14962                                             NaN
# 84040                                     Equipment *
# 61639                                             NaN
# 266302                                            NaN
# 225768  Extra Duty Pay/Overtime For Support Personnel
# 267322                                            NaN
# 308098  Extra Duty Pay/Overtime For Support Personnel
# 227367                             Purchased Services
# 329096                                            NaN
# 282308                                            NaN
# ...                                               ...
# 209265                                            NaN
# 333748      Certificated Employees Salaries And Wages
# 292626  Extra Duty Pay/Overtime For Support Personnel
# 343458                                            NaN
# 128261                                            NaN
# 186318                                            NaN
# 210652                                            NaN
# 340354                                            NaN
# 435205                                            NaN
# 174827                                            NaN
# 277504                                            NaN
# 248062         Travel And Subsistence - Employee Only
# 70455                                             NaN
# 203453                                            NaN
# 58170                                             NaN
# 68311                                             NaN
# 225892                                            NaN
# 446383                         Pupil Transportation *
# 155111  Extra Duty Pay/Overtime For Support Personnel
# 278248                                            NaN
# 397424                                            NaN
# 375092                                            NaN
# 220181        Salaries Or Wages For Support Personnel
# 307423                            Awards And Prizes *
# 46691                                             NaN
# 109283                                            NaN
# 102430                                            NaN
# 413949                                            NaN
# 433672                                            NaN
# 415831     Inservice Substitute Teachers Grant Funded
#
#                   Location_Description  \
# 134338                             NaN
# 326408                             NaN
# 364634                             NaN
# 47683                              NaN
# 229958                             NaN
# 417668                             NaN
# 126378  DISTRICT WIDE ORGANIZATION UNI
# 85262                              NaN
# 304569                             NaN
# 84272                              NaN
# 64760                              NaN
# 21870                          CHARTER
# 169454                         School
# 169914    SAFETY AND SECURITY DIVISION
# 189701                             NaN
# 43727                              NaN
# 5614                               NaN
# 307038      SR OTH CERTIFICATED PERSON
# 27645                          CHARTER
# 126388                             NaN
# 14962                              NaN
# 84040                              NaN
# 61639                              NaN
# 266302                             NaN
# 225768                   Undistributed
# 267322                             NaN
# 308098                   Undistributed
# 227367                             NaN
# 329096                             NaN
# 282308                         School
# ...                                ...
# 209265                             NaN
# 333748      PSYCHOLOGICAL SERVICES OFF
# 292626                     Unallocated
# 343458       ALL SCHOOLS-UNDISTRIBUTED
# 128261                             NaN
# 186318                             NaN
# 210652                             NaN
# 340354                             NaN
# 435205                             NaN
# 174827                             NaN
# 277504                             NaN
# 248062                         School
# 70455                          School
# 203453                         School
# 58170                              NaN
# 68311                   MATH / SCIENCE
# 225892                             NaN
# 446383                             NaN
# 155111                     Unallocated
# 278248                             NaN
# 397424                             NaN
# 375092                             NaN
# 220181                         School
# 307423                             NaN
# 46691                   MATH / SCIENCE
# 109283  STAFF DEV AND INSTR MEDIA
# 102430                             NaN
# 413949                             NaN
# 433672            ED RESOURCE SERVICES
# 415831                         School
#
#                                      Function_Description  \
# 134338                                                NaN
# 326408                                                NaN
# 364634                            UNALLOC BUDGETS/SCHOOLS
# 47683                                         NON-PROJECT
# 229958                                        NON-PROJECT
# 417668                                                NaN
# 126378                                        NON-PROJECT
# 85262                             UNALLOC BUDGETS/SCHOOLS
# 304569  State and Federal Projects Coordination Services*
# 84272                                                 NaN
# 64760                               Disadvantaged Youth *
# 21870                      BASIC (FEFP K-12)
# 169454                     BASIC (FEFP K-12)
# 169914                                  Security Services
# 189701                                        NON-PROJECT
# 43727   Instruction And Curriculum Development Services *
# 5614             Direction Of Support Services - Pupils *
# 307038                              Disadvantaged Youth *
# 27645                      GUIDANCE SERVICES
# 126388                                                NaN
# 14962                                                 NaN
# 84040   Instruction And Curriculum Development Services *
# 61639                                        CORE MATTERS
# 266302                       ELA E-TEACHING SHELTERED ENG
# 225768                                     Transportation
# 267322                                        NON-PROJECT
# 308098                                     Transportation
# 227367                         Other Community Services *
# 329096                                        NON-PROJECT
# 282308                     FOOD SERVICE
# ...                                                   ...
# 209265                                                NaN
# 333748                           Psychological Services *
# 292626            Facilities Acquisition And Construction
# 343458                            UNALLOC BUDGETS/SCHOOLS
# 128261                         SPECIAL ED. - SEVERE NEEDS
# 186318                      ELA S - TEACHING SPANISH ONLY
# 210652                                                NaN
# 340354                                     TITLE III  ELA
# 435205                        READ TO ACHIEVE ROUND THREE
# 174827                                            TITLE I
# 277504                                        NON-PROJECT
# 248062  Curriculum Development And Instructional Staff...
# 70455                      BASIC (FEFP K-12)
# 203453                     STAFF SERVICES
# 58170                                                 NaN
# 68311                      TITLE II-PART A-TEACHER QUALIT
# 225892                       ELA E-TEACHING SHELTERED ENG
# 446383  Instruction And Curriculum Development Services *
# 155111                                     Transportation
# 278248                                        INSTRUCTION
# 397424                                            NS  GOB
# 375092                                                NaN
# 220181          Food Services (Child Nutrition Fund Only)
# 307423       Other Improvements Of Instruction Services *
# 46691                      TITLE II-PART A-TEACHER QUALIT
# 109283                     INST STAFF TRAINING SVCS
# 102430                                         TITLE II,D
# 413949                                                NaN
# 433672                                        NON-PROJECT
# 415831                                        Instruction
#
#                             Facility_or_Department  \
# 134338                                         NaN
# 326408                                         NaN
# 364634                                         NaN
# 47683                                          NaN
# 229958                                         NaN
# 417668                                         NaN
# 126378                                         NaN
# 85262                                          NaN
# 304569                                         NaN
# 84272                       POSITION CONTROL POOLS
# 64760                                          NaN
# 21870                                          NaN
# 169454                                         NaN
# 169914                                         NaN
# 189701                                         NaN
# 43727                                          NaN
# 5614                                           NaN
# 307038                                         NaN
# 27645                                          NaN
# 126388                                         NaN
# 14962                                          NaN
# 84040                                          NaN
# 61639                                          NaN
# 266302                                         NaN
# 225768                   Transportation Department
# 267322                                         NaN
# 308098                   Transportation Department
# 227367                                         NaN
# 329096                                         NaN
# 282308                                         NaN
# ...                                            ...
# 209265                                         NaN
# 333748                                         NaN
# 292626  New Construction Department Administration
# 343458                                         NaN
# 128261                                         NaN
# 186318                                         NaN
# 210652                              TEACHER SUPPLY
# 340354                                         NaN
# 435205                                         NaN
# 174827                                         NaN
# 277504                                         NaN
# 248062                                  Vocational
# 70455                                          NaN
# 203453                                         NaN
# 58170                                          NaN
# 68311                                          NaN
# 225892                                         NaN
# 446383                                         NaN
# 155111                   Transportation Department
# 278248                                         NaN
# 397424                                         NaN
# 375092                                         NaN
# 220181                             Child Nutrition
# 307423                                         NaN
# 46691                                          NaN
# 109283                                         NaN
# 102430                                         NaN
# 413949                                         NaN
# 433672                                         NaN
# 415831                  Instruction And Curriculum
#
#                        Position_Extra             Program_Description  \
# 134338                  KINDERGARTEN                     KINDERGARTEN
# 326408                        TEACHER           Instruction - Regular
# 364634     PROFESSIONAL-INSTRUCTIONAL  GENERAL MIDDLE/JUNIOR HIGH SCH
# 47683      PROFESSIONAL-INSTRUCTIONAL   GENERAL HIGH SCHOOL EDUCATION
# 229958                   UNDESIGNATED               EMPLOYEE BENEFITS
# 417668         SUPPLIES AND MATERIALS         SPECIAL EDUCATION LOCAL
# 126378                   UNDESIGNATED                    UNDESIGNATED
# 85262      PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 304569                            NaN                             NaN
# 84272                         TEACHER           Instruction - Regular
# 64760                             NaN                             NaN
# 21870                             NaN                             NaN
# 169454                            NaN                             NaN
# 169914                            NaN                             NaN
# 189701                   UNDESIGNATED  CARE & UPKEEP OF BLDG SERVICES
# 43727                             NaN                             NaN
# 5614                              NaN                             NaN
# 307038                            NaN                             NaN
# 27645                             NaN                             NaN
# 126388             SUBSTITUTE TEACHER           Instruction - Regular
# 14962                 TEACHER -  DAYS           Instruction - Regular
# 84040                             NaN                             NaN
# 61639      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 266302     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 225768                     BUS DRIVER                   Undistributed
# 267322                   UNDESIGNATED               EMPLOYEE BENEFITS
# 308098                     BUS DRIVER                   Undistributed
# 227367                            NaN                             NaN
# 329096   CRAFTS, TRADES, AND SERVICES        FOOD PREPARATION/SERVING
# 282308                            NaN                             NaN
# ...                               ...                             ...
# 209265                    MS ENGLISH       MIDDLE SCHOOL PROGRAM  6-8
# 333748                            NaN                             NaN
# 292626         DIR EXEC DIR SECRETARY                   Undistributed
# 343458     PROFESSIONAL-INSTRUCTIONAL         OTHER GENERAL EDUCATION
# 128261     PROFESSIONAL-INSTRUCTIONAL      SPECIAL EDUCATION-TMD HIGH
# 186318     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 210652             SUBSTITUTE TEACHER              Instruction - SPED
# 340354               PARAPROFESSIONAL   GENERAL HIGH SCHOOL EDUCATION
# 435205     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 174827               PARAPROFESSIONAL    GENERAL ELEMENTARY EDUCATION
# 277504                   UNDESIGNATED               EMPLOYEE BENEFITS
# 248062                            NaN           Career And Technology
# 70455                             NaN                             NaN
# 203453                            NaN                             NaN
# 58170              SUBSTITUTE TEACHER   Support - Regular Instruction
# 68311      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 225892     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 446383                            NaN                             NaN
# 155111     RADIO & SUBSTITUTE DRIVERS                   Undistributed
# 278248                            NaN         PRIMARY GRADES PROGRAM
# 397424               PARAPROFESSIONAL  GENERAL MIDDLE/JUNIOR HIGH SCH
# 375092             SUBSTITUTE TEACHER           Instruction - Regular
# 220181       REG FOOD SERVICE WORKER                    Undistributed
# 307423                            NaN                             NaN
# 46691      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 109283                            NaN                             NaN
# 102430     PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 413949                 PARENT/TITLE I                            Misc
# 433672  OFFICE/ADMINISTRATIVE SUPPORT          MEDIA SUPPORT SERVICES
# 415831           CERTIFIED SUBSTITUTE           Accelerated Education
#
#                                          Fund_Description  \
# 134338                                       General Fund
# 326408                             General Purpose School
# 364634                                                NaN
# 47683                                                 NaN
# 229958                                                NaN
# 417668                                         LOCAL FUND
# 126378                                                NaN
# 85262                                                 NaN
# 304569                                     School to Work
# 84272                              General Purpose School
# 64760   Title I - Disadvantaged Children/Targeted Assi...
# 21870                      CONVERSION CHARTER SCHOOLS
# 169454                     GENERAL FUND
# 169914                                            General
# 189701                                                NaN
# 43727                                       Special Trust
# 5614                                        Special Trust
# 307038  Title I - Disadvantaged Children/Targeted Assi...
# 27645                      CONVERSION CHARTER SCHOOLS
# 126388                             General Purpose School
# 14962                             School Federal Projects
# 84040                                       Special Trust
# 61639                                                 NaN
# 266302                                                NaN
# 225768                             General Operating Fund
# 267322                                                NaN
# 308098                             General Operating Fund
# 227367  Title I - Disadvantaged Children/Targeted Assi...
# 329096                                                NaN
# 282308                     FOOD SERVICES
# ...                                                   ...
# 209265                                       General Fund
# 333748                                            General
# 292626                             General Operating Fund
# 343458                                                NaN
# 128261                                                NaN
# 186318                                                NaN
# 210652                            School Federal Projects
# 340354                                                NaN
# 435205                                                NaN
# 174827                                                NaN
# 277504                                                NaN
# 248062                             General Operating Fund
# 70455                      CONVERSION CHARTER SCHOOLS
# 203453                     EXTENDED LEARNING CENTER ELC
# 58170                             School Federal Projects
# 68311                                                 NaN
# 225892                                                NaN
# 446383                                      Special Trust
# 155111                             General Operating Fund
# 278248                                       General Fund
# 397424                                                NaN
# 375092                             General Purpose School
# 220181        National School Breakfast And Lunch Program
# 307423                         Miscellaneous State Grants
# 46691                                                 NaN
# 109283                     GENERAL FUND
# 102430                                                NaN
# 413949                                 Schoolwide Schools
# 433672                                                NaN
# 415831           "Title  Part A Improving Basic Programs"
#
#                                           Text_1
# 134338                                       NaN
# 326408                                       NaN
# 364634                       REGULAR INSTRUCTION
# 47683                        REGULAR INSTRUCTION
# 229958                         EMPLOYEE BENEFITS
# 417668                                       NaN
# 126378                              UNDESIGNATED
# 85262                        REGULAR INSTRUCTION
# 304569                ITEMAI-CITY-YTH EMP & OPP
# 84272                                        NaN
# 64760                                   TITLE I
# 21870                                        NaN
# 169454            TEACHER LEAD
# 169914                         SAFETY & SECURITY
# 189701              OPERATION AND MAINT OF PLANT
# 43727                      RESP SEXUAL BEHAVIOR
# 5614                        HOME TEAM MARKETING
# 307038                      BUILDING ALLOCATIONS
# 27645                                        NaN
# 126388                                       NaN
# 14962                 ESEA TITLE I DISADVANTAGED
# 84040                  KEY BANK NATIONAL ASSOCIA
# 61639                        INSTRUCTIONAL STAFF
# 266302                       REGULAR INSTRUCTION
# 225768             ADDL REGULAR PAY-NOT SMOOTHED
# 267322                         EMPLOYEE BENEFITS
# 308098                                  OVERTIME
# 227367                 TITLE I - PARENT INVOLVEM
# 329096                  FOOD SERVICES OPERATIONS
# 282308                                       NaN
# ...                                          ...
# 209265                                       NaN
# 333748                    PSYCHOLOGICAL SERVICES
# 292626                                  OVERTIME
# 343458                       REGULAR INSTRUCTION
# 128261                         SPECIAL EDUCATION
# 186318                       REGULAR INSTRUCTION
# 210652  INDIVIDUALS WITH DISABILITIES ACT PART B
# 340354                       REGULAR INSTRUCTION
# 435205                       REGULAR INSTRUCTION
# 174827                       REGULAR INSTRUCTION
# 277504                         EMPLOYEE BENEFITS
# 248062                                       NaN
# 70455                                        NaN
# 203453                                       NaN
# 58170                                      OTHER
# 68311                        INSTRUCTIONAL STAFF
# 225892                       REGULAR INSTRUCTION
# 446383                    ITEMS FOUNDATION-JUNE
# 155111                                  OVERTIME
# 278248                                       NaN
# 397424                       REGULAR INSTRUCTION
# 375092                                       NaN
# 220181                               REGULAR PAY
# 307423                  SCHOOL IMPROV INCENTIVES
# 46691                        INSTRUCTIONAL STAFF
# 109283            STAFF DEV AND INSTR MEDIA
# 102430                       INSTRUCTIONAL STAFF
# 413949                                       NaN
# 433672                       INSTRUCTIONAL STAFF
# 415831                            MISCELLANEOUS
#
# [320222 rows x 14 columns]
#  THE SHAPE OF NEW TEXT DATA
# --------------------
#
#
# (320222, 14)
#
#
# Now the New TEXT DATA IS:
# -----------------------------
#
#
#
#                                        Object_Description  \
# 134338
# 326408                       Personal Services - Teachers
# 364634                                  EMPLOYEE BENEFITS
# 47683                        TEACHER COVERAGE FOR TEACHER
# 229958                                    CONTRA BENEFITS
# 417668                                        EDUCATIONAL
# 126378                                  EMPLOYEE BENEFITS
# 85262                                   EMPLOYEE BENEFITS
# 304569                                        EQUIPMENT *
# 84272                        Personal Services - Teachers
# 64760                                           Regular *
# 21870                      OTHER PERSONAL SERVICES
# 169454                     SUPPLIES
# 169914                                          Regular *
# 189701                                        ELECTRICITY
# 43727               Non-Certificated Travel Reimbursement
# 5614                                   Purchased Services
# 307038                                          Regular *
# 27645                      BONUSES
# 126388  Personal Services - Substitute Teachers Certified
# 14962                        Personal Services - Teachers
# 84040                                         EQUIPMENT *
# 61639                                   EMPLOYEE BENEFITS
# 266302                                  EMPLOYEE BENEFITS
# 225768      Extra Duty Pay/Overtime For Support Personnel
# 267322                                    CONTRA BENEFITS
# 308098      Extra Duty Pay/Overtime For Support Personnel
# 227367                                 Purchased Services
# 329096                      SALARIES OF REGULAR EMPLOYEES
# 282308                     OTHER SUPPORT PERSONNEL
# ...                                                   ...
# 209265
# 333748                                          Regular *
# 292626      Extra Duty Pay/Overtime For Support Personnel
# 343458                     SALARIES OF PART TIME EMPLOYEE
# 128261                      SALARIES OF REGULAR EMPLOYEES
# 186318                      SALARIES OF REGULAR EMPLOYEES
# 210652  Personal Services - Substitute Teachers Non-Ce...
# 340354                                  EMPLOYEE BENEFITS
# 435205                       EMPLOYER PD MED CONTRIBUTION
# 174827                     SALARIES OF PART TIME EMPLOYEE
# 277504                                    CONTRA BENEFITS
# 248062             Travel And Subsistence - Employee Only
# 70455                      CLASSROOM TEACHER
# 203453                     IN-COUNTY TRAVEL
# 58170   Personal Services - Substitute Teachers Certified
# 68311                      ADDITIONAL/EXTRA DUTY PAY/STIP
# 225892                      SALARIES OF REGULAR EMPLOYEES
# 446383                Other Pupil Transportation Services
# 155111      Extra Duty Pay/Overtime For Support Personnel
# 278248                                           SUPPLIES
# 397424                     ADDITIONAL/EXTRA DUTY PAY/STIP
# 375092  Personal Services - Substitute Teachers Certified
# 220181            Salaries Or Wages For Support Personnel
# 307423                            Other Awards and Prizes
# 46691                      ADDITIONAL/EXTRA DUTY PAY/STIP
# 109283                     WORKSHOP PARTICIPANT
# 102430                     SALARIES OF PART TIME EMPLOYEE
# 413949
# 433672                                  EMPLOYEE BENEFITS
# 415831    Salaries And Wages For Substitute Professionals
#
#                                Text_2  \
# 134338
# 326408
# 364634                   TEACHER SUBS
# 47683                    TEACHER SUBS
# 229958
# 417668  SPECIAL EDUCATION INSTRUCTION
# 126378
# 85262                    TEACHER SUBS
# 304569
# 84272
# 64760
# 21870
# 169454
# 169914                       ADM/PROF
# 189701         OPERATIONS - UTILITIES
# 43727
# 5614
# 307038                        TEACHER
# 27645
# 126388
# 14962
# 84040
# 61639
# 266302
# 225768
# 267322
# 308098
# 227367
# 329096                  FOOD SERVICES
# 282308
# ...                               ...
# 209265
# 333748                     TEACHERSUP
# 292626
# 343458                   TEACHER SUBS
# 128261            SEVERE DISABILITIES
# 186318
# 210652
# 340354
# 435205
# 174827
# 277504
# 248062
# 70455
# 203453
# 58170
# 68311                    MATH/SCIENCE
# 225892
# 446383
# ...
# 203453                     STAFF SERVICES
# 58170
# 68311                      TITLE II-PART A-TEACHER QUALIT
# 225892                       ELA E-TEACHING SHELTERED ENG
# 446383  Instruction And Curriculum Development Services *
# 155111                                     Transportation
# 278248                                        INSTRUCTION
# 397424                                            NS  GOB
# 375092
# 220181          Food Services (Child Nutrition Fund Only)
# 307423       Other Improvements Of Instruction Services *
# 46691                      TITLE II-PART A-TEACHER QUALIT
# 109283                     INST STAFF TRAINING SVCS
# 102430                                         TITLE II,D
# 413949
# 433672                                        NON-PROJECT
# 415831                                        Instruction
#
#                             Facility_or_Department  \
# 134338
# 326408
# 364634
# 47683
# 229958
# 417668
# 126378
# 85262
# 304569
# 84272                       POSITION CONTROL POOLS
# 64760
# 21870
# 169454
# 169914
# 189701
# 43727
# 5614
# 307038
# 27645
# 126388
# 14962
# 84040
# 61639
# 266302
# 225768                   Transportation Department
# 267322
# 308098                   Transportation Department
# 227367
# 329096
# 282308
# ...                                            ...
# 209265
# 333748
# 292626  New Construction Department Administration
# 343458
# 128261
# 186318
# 210652                              TEACHER SUPPLY
# 340354
# 435205
# 174827
# 277504
# 248062                                  Vocational
# 70455
# 203453
# 58170
# 68311
# 225892
# 446383
# 155111                   Transportation Department
# 278248
# 397424
# 375092
# 220181                             Child Nutrition
# 307423
# 46691
# 109283
# 102430
# 413949
# 433672
# 415831                  Instruction And Curriculum
#
#                        Position_Extra             Program_Description  \
# 134338                  KINDERGARTEN                     KINDERGARTEN
# 326408                        TEACHER           Instruction - Regular
# 364634     PROFESSIONAL-INSTRUCTIONAL  GENERAL MIDDLE/JUNIOR HIGH SCH
# 47683      PROFESSIONAL-INSTRUCTIONAL   GENERAL HIGH SCHOOL EDUCATION
# 229958                   UNDESIGNATED               EMPLOYEE BENEFITS
# 417668         SUPPLIES AND MATERIALS         SPECIAL EDUCATION LOCAL
# 126378                   UNDESIGNATED                    UNDESIGNATED
# 85262      PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 304569
# 84272                         TEACHER           Instruction - Regular
# 64760
# 21870
# 169454
# 169914
# 189701                   UNDESIGNATED  CARE & UPKEEP OF BLDG SERVICES
# 43727
# 5614
# 307038
# 27645
# 126388             SUBSTITUTE TEACHER           Instruction - Regular
# 14962                 TEACHER -  DAYS           Instruction - Regular
# 84040
# 61639      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 266302     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 225768                     BUS DRIVER                   Undistributed
# 267322                   UNDESIGNATED               EMPLOYEE BENEFITS
# 308098                     BUS DRIVER                   Undistributed
# 227367
# 329096   CRAFTS, TRADES, AND SERVICES        FOOD PREPARATION/SERVING
# 282308
# ...                               ...                             ...
# 209265                    MS ENGLISH       MIDDLE SCHOOL PROGRAM  6-8
# 333748
# 292626         DIR EXEC DIR SECRETARY                   Undistributed
# 343458     PROFESSIONAL-INSTRUCTIONAL         OTHER GENERAL EDUCATION
# 128261     PROFESSIONAL-INSTRUCTIONAL      SPECIAL EDUCATION-TMD HIGH
# 186318     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 210652             SUBSTITUTE TEACHER              Instruction - SPED
# 340354               PARAPROFESSIONAL   GENERAL HIGH SCHOOL EDUCATION
# 435205     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 174827               PARAPROFESSIONAL    GENERAL ELEMENTARY EDUCATION
# 277504                   UNDESIGNATED               EMPLOYEE BENEFITS
# 248062                                          Career And Technology
# 70455
# 203453
# 58170              SUBSTITUTE TEACHER   Support - Regular Instruction
# 68311      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 225892     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 446383
# 155111     RADIO & SUBSTITUTE DRIVERS                   Undistributed
# 278248                                        PRIMARY GRADES PROGRAM
# 397424               PARAPROFESSIONAL  GENERAL MIDDLE/JUNIOR HIGH SCH
# 375092             SUBSTITUTE TEACHER           Instruction - Regular
# 220181       REG FOOD SERVICE WORKER                    Undistributed
# 307423
# 46691      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 109283
# 102430     PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 413949                 PARENT/TITLE I                            Misc
# 433672  OFFICE/ADMINISTRATIVE SUPPORT          MEDIA SUPPORT SERVICES
# 415831           CERTIFIED SUBSTITUTE           Accelerated Education
#
#                                          Fund_Description  \
# 134338                                       General Fund
# 326408                             General Purpose School
# 364634
# 47683
# 229958
# 417668                                         LOCAL FUND
# 126378
# 85262
# 304569                                     School to Work
# 84272                              General Purpose School
# 64760   Title I - Disadvantaged Children/Targeted Assi...
# 21870                      CONVERSION CHARTER SCHOOLS
# 169454                     GENERAL FUND
# 169914                                            General
# 189701
# 43727                                       Special Trust
# 5614                                        Special Trust
# 307038  Title I - Disadvantaged Children/Targeted Assi...
# 27645                      CONVERSION CHARTER SCHOOLS
# 126388                             General Purpose School
# 14962                             School Federal Projects
# 84040                                       Special Trust
# 61639
# 266302
# 225768                             General Operating Fund
# 267322
# 308098                             General Operating Fund
# 227367  Title I - Disadvantaged Children/Targeted Assi...
# 329096
# 282308                     FOOD SERVICES
# ...                                                   ...
# 209265                                       General Fund
# 333748                                            General
# 292626                             General Operating Fund
# 343458
# 128261
# 186318
# 210652                            School Federal Projects
# 340354
# 435205
# 174827
# 277504
# 248062                             General Operating Fund
# 70455                      CONVERSION CHARTER SCHOOLS
# 203453                     EXTENDED LEARNING CENTER ELC
# 58170                             School Federal Projects
# 68311
# 225892
# 446383                                      Special Trust
# 155111                             General Operating Fund
# 278248                                       General Fund
# 397424
# 375092                             General Purpose School
# 220181        National School Breakfast And Lunch Program
# 307423                         Miscellaneous State Grants
# 46691
# 109283                     GENERAL FUND
# 102430
# 413949                                 Schoolwide Schools
# 433672
# 415831           "Title  Part A Improving Basic Programs"
#
#                                           Text_1
# 134338
# 326408
# 364634                       REGULAR INSTRUCTION
# 47683                        REGULAR INSTRUCTION
# 229958                         EMPLOYEE BENEFITS
# 417668
# 126378                              UNDESIGNATED
# 85262                        REGULAR INSTRUCTION
# 304569                ITEMAI-CITY-YTH EMP & OPP
# 84272
# 64760                                   TITLE I
# 21870
# 169454            TEACHER LEAD
# 169914                         SAFETY & SECURITY
# 189701              OPERATION AND MAINT OF PLANT
# 43727                      RESP SEXUAL BEHAVIOR
# 5614                        HOME TEAM MARKETING
# 307038                      BUILDING ALLOCATIONS
# 27645
# 126388
# 14962                 ESEA TITLE I DISADVANTAGED
# 84040                  KEY BANK NATIONAL ASSOCIA
# 61639                        INSTRUCTIONAL STAFF
# 266302                       REGULAR INSTRUCTION
# 225768             ADDL REGULAR PAY-NOT SMOOTHED
# 267322                         EMPLOYEE BENEFITS
# 308098                                  OVERTIME
# 227367                 TITLE I - PARENT INVOLVEM
# 329096                  FOOD SERVICES OPERATIONS
# 282308
# ...                                          ...
# 209265
# 333748                    PSYCHOLOGICAL SERVICES
# 292626                                  OVERTIME
# 343458                       REGULAR INSTRUCTION
# 128261                         SPECIAL EDUCATION
# 186318                       REGULAR INSTRUCTION
# 210652  INDIVIDUALS WITH DISABILITIES ACT PART B
# 340354                       REGULAR INSTRUCTION
# 435205                       REGULAR INSTRUCTION
# 174827                       REGULAR INSTRUCTION
# 277504                         EMPLOYEE BENEFITS
# 248062
# 70455
# 203453
# 58170                                      OTHER
# 68311                        INSTRUCTIONAL STAFF
# 225892                       REGULAR INSTRUCTION
# 446383                    ITEMS FOUNDATION-JUNE
# 155111                                  OVERTIME
# 278248
# 397424                       REGULAR INSTRUCTION
# 375092
# 220181                               REGULAR PAY
# 307423                  SCHOOL IMPROV INCENTIVES
# 46691                        INSTRUCTIONAL STAFF
# 109283            STAFF DEV AND INSTR MEDIA
# 102430                       INSTRUCTIONAL STAFF
# 413949
# 433672                       INSTRUCTIONAL STAFF
# 415831                            MISCELLANEOUS
#
# [320222 rows x 14 columns]
#           0
# 0  0.377964
# 1  0.755929
# 2  0.377964
# 3  0.377964
# 4  0.235702

# %% [markdown]
# Some text is hashed to the same value, but this doesn't neccessarily hurt performance.

# %%
# Import the hashing vectorizer
from sklearn.feature_extraction.text import HashingVectorizer
# Instantiate the winning model pipeline: pl
pl = Pipeline([
        ('union', FeatureUnion(
            transformer_list = [
                ('numeric_features', Pipeline([
                    ('selector', get_numeric_data),
                    ('imputer', Imputer())
                ])),
                ('text_features', Pipeline([
                    ('selector', get_text_data),
                    ('vectorizer', HashingVectorizer(token_pattern=TOKENS_ALPHANUMERIC,
                                                     non_negative=True, norm=None, binary=False,
                                                     ngram_range=(1,2))),
                    ('dim_red', SelectKBest(chi2, chi_k))
                ]))
             ]
        )),
        ('int', SparseInteractions(degree=2)),
        ('scale', MaxAbsScaler()),
        ('clf', OneVsRestClassifier(LogisticRegression()))
    ])
# Out:
# The Initial To_Drop contains
# ---------------------------------
#
#
# ['FTE', 'Total', 'Function', 'Use', 'Sharing', 'Reporting', 'Student_Type', 'Position_Type', 'Object_Type', 'Pre_K', 'Operating_Status']
#
#
#
#
# The Initial Columns of the DataFrame are:
# ----------------------------------------
#
#
# ['Object_Description', 'Text_2', 'SubFund_Description', 'Job_Title_Description', 'Text_3', 'Text_4', 'Sub_Object_Description', 'Location_Description', 'FTE', 'Function_Description', 'Facility_or_Department', 'Position_Extra', 'Total', 'Program_Description', 'Fund_Description', 'Text_1']
#
#
#
#
# The Final To_Drop Contains :
# ---------------------------------
#
#
# {'Total', 'FTE'}
#
#
#  THE SHAPE OF TEXT DATA
# --------------------
#
#
# (320222, 14)
#
#
# THE TEXT DATA IS:
# --------------------
#
#
#                                        Object_Description  \
# 134338                                                NaN
# 326408                       Personal Services - Teachers
# 364634                                  EMPLOYEE BENEFITS
# 47683                        TEACHER COVERAGE FOR TEACHER
# 229958                                    CONTRA BENEFITS
# 417668                                        EDUCATIONAL
# 126378                                  EMPLOYEE BENEFITS
# 85262                                   EMPLOYEE BENEFITS
# 304569                                        EQUIPMENT *
# 84272                        Personal Services - Teachers
# 64760                                           Regular *
# 21870                      OTHER PERSONAL SERVICES
# 169454                     SUPPLIES
# 169914                                          Regular *
# 189701                                        ELECTRICITY
# 43727               Non-Certificated Travel Reimbursement
# 5614                                   Purchased Services
# 307038                                          Regular *
# 27645                      BONUSES
# 126388  Personal Services - Substitute Teachers Certified
# 14962                        Personal Services - Teachers
# 84040                                         EQUIPMENT *
# 61639                                   EMPLOYEE BENEFITS
# 266302                                  EMPLOYEE BENEFITS
# 225768      Extra Duty Pay/Overtime For Support Personnel
# 267322                                    CONTRA BENEFITS
# 308098      Extra Duty Pay/Overtime For Support Personnel
# 227367                                 Purchased Services
# 329096                      SALARIES OF REGULAR EMPLOYEES
# 282308                     OTHER SUPPORT PERSONNEL
# ...                                                   ...
# 209265                                                NaN
# 333748                                          Regular *
# 292626      Extra Duty Pay/Overtime For Support Personnel
# 343458                     SALARIES OF PART TIME EMPLOYEE
# 128261                      SALARIES OF REGULAR EMPLOYEES
# 186318                      SALARIES OF REGULAR EMPLOYEES
# 210652  Personal Services - Substitute Teachers Non-Ce...
# 340354                                  EMPLOYEE BENEFITS
# 435205                       EMPLOYER PD MED CONTRIBUTION
# 174827                     SALARIES OF PART TIME EMPLOYEE
# 277504                                    CONTRA BENEFITS
# 248062             Travel And Subsistence - Employee Only
# 70455                      CLASSROOM TEACHER
# 203453                     IN-COUNTY TRAVEL
# 58170   Personal Services - Substitute Teachers Certified
# 68311                      ADDITIONAL/EXTRA DUTY PAY/STIP
# 225892                      SALARIES OF REGULAR EMPLOYEES
# 446383                Other Pupil Transportation Services
# 155111      Extra Duty Pay/Overtime For Support Personnel
# 278248                                           SUPPLIES
# 397424                     ADDITIONAL/EXTRA DUTY PAY/STIP
# 375092  Personal Services - Substitute Teachers Certified
# 220181            Salaries Or Wages For Support Personnel
# 307423                            Other Awards and Prizes
# 46691                      ADDITIONAL/EXTRA DUTY PAY/STIP
# 109283                     WORKSHOP PARTICIPANT
# 102430                     SALARIES OF PART TIME EMPLOYEE
# 413949                                                NaN
# 433672                                  EMPLOYEE BENEFITS
# 415831    Salaries And Wages For Substitute Professionals
#
#                                Text_2  \
# 134338                            NaN
# 326408                            NaN
# 364634                   TEACHER SUBS
# 47683                    TEACHER SUBS
# 229958                            NaN
# 417668  SPECIAL EDUCATION INSTRUCTION
# 126378                            NaN
# 85262                    TEACHER SUBS
# 304569                            NaN
# 84272                             NaN
# 64760                             NaN
# 21870                             NaN
# 169454                            NaN
# 169914                       ADM/PROF
# 189701         OPERATIONS - UTILITIES
# 43727                             NaN
# 5614                              NaN
# 307038                        TEACHER
# 27645                             NaN
# 126388                            NaN
# 14962                             NaN
# 84040                             NaN
# 61639                             NaN
# 266302                            NaN
# 225768                            NaN
# 267322                            NaN
# 308098                            NaN
# 227367                            NaN
# 329096                  FOOD SERVICES
# 282308                            NaN
# ...                               ...
# 209265                            NaN
# 333748                     TEACHERSUP
# 292626                            NaN
# 343458                   TEACHER SUBS
# 128261            SEVERE DISABILITIES
# 186318                            NaN
# 210652                            NaN
# 340354                            NaN
# 435205                            NaN
# 174827                            NaN
# 277504                            NaN
# 248062                            NaN
# 70455                             NaN
# 203453                            NaN
# 58170                             NaN
# 68311                    MATH/SCIENCE
# 225892                            NaN
# 446383                            NaN
# 155111                            NaN
# 278248                            NaN
# 397424                            NaN
# 375092                            NaN
# 220181                            NaN
# 307423                            NaN
# 46691                    MATH/SCIENCE
# 109283                            NaN
# 102430                            NaN
# 413949                            NaN
# 433672  EDUCATIONAL RESOURCE SERVICES
# 415831                            NaN
#
#                                 SubFund_Description  \
# 134338                                          NaN
# 326408                                          NaN
# 364634                                 GENERAL FUND
# 47683                                  GENERAL FUND
# 229958                                 GENERAL FUND
# 417668                                        LOCAL
# 126378                                 GENERAL FUND
# 85262                                  GENERAL FUND
# 304569            Support Services - Administration
# 84272                                           NaN
# 64760                           Special Instruction
# 21870                                           NaN
# 169454                                          NaN
# 169914  Operation and Maintenance of Plant Services
# 189701                                 GENERAL FUND
# 43727        Support Services - Instructional Staff
# 5614                       Support Services--Pupils
# 307038                          Special Instruction
# 27645                                           NaN
# 126388                                          NaN
# 14962                                           NaN
# 84040        Support Services - Instructional Staff
# 61639                                  GENERAL FUND
# 266302                                 GENERAL FUND
# 225768                                   Operations
# 267322                                 GENERAL FUND
# 308098                                   Operations
# 227367                           Community Services
# 329096                            FOOD SERVICE FUND
# 282308                                          NaN
# ...                                             ...
# 209265                                          NaN
# 333748                     Support Services--Pupils
# 292626                                   Operations
# 343458                                 GENERAL FUND
# 128261                                 GENERAL FUND
# 186318                                 GENERAL FUND
# 210652                                          NaN
# 340354                      FEDERAL GDPG FUND - FY
# 435205                    STATE AND LOCAL GDPG FUND
# 174827                      FEDERAL GDPG FUND - FY
# 277504                                 GENERAL FUND
# 248062                                          NaN
# 70455                                           NaN
# 203453                                          NaN
# 58170                                           NaN
# 68311                       FEDERAL GDPG FUND - FY
# 225892                                 GENERAL FUND
# 446383       Support Services - Instructional Staff
# 155111                                   Operations
# 278248                      PRIMARY GRADES PROGRAM
# 397424                                         BOND
# 375092                                          NaN
# 220181                              Child Nutrition
# 307423       Support Services - Instructional Staff
# 46691                       FEDERAL GDPG FUND - FY
# 109283                                          NaN
# 102430                      FEDERAL GDPG FUND - FY
# 413949                                          NaN
# 433672                                LEVY OVERRIDE
# 415831     "Title  Part A Improving Basic Programs"
#
#                          Job_Title_Description       Text_3  \
# 134338                     Teacher-Elementary           NaN
# 326408                         TCHER 2ND GRADE          NaN
# 364634                Teacher, Short Term Sub       Regular
# 47683               Teacher, Secondary (High)   Alternative
# 229958                 Custodian - PT -  Jobs           n/a
# 417668                                     NaN          NaN
# 126378              Sub Manager, Food Service           n/a
# 85262             Teacher,Retrd Shrt Term Sub       Regular
# 304569                                     NaN          NaN
# 84272   TCHER P E (ELEM POSITION CONTROL POOL)          NaN
# 64760                                      NaN          NaN
# 21870           SUB TEACHER ALL                         NaN
# 169454          TEACHER, TITLE I-ELEM                   NaN
# 169914              ADMIN LIEUTENANT COMM SERV          NaN
# 189701                                 (blank)      Regular
# 43727                                      NaN          NaN
# 5614                                       NaN          NaN
# 307038                     TCHR, SCNDY ENGLISH          NaN
# 27645           ESE CLERICAL ASSISTANT II               NaN
# 126388                                     NaN          NaN
# 14962                TCHER ENGLISH (SECONDARY)          NaN
# 84040                                      NaN          NaN
# 61639                 Teacher, Short Term Sub       Regular
# 266302                    Teacher, Elementary       Regular
# 225768          TRANSPORTATION,BUS DRIVERS,REG          NaN
# 267322             Teacher,Spec Ed Center Prg           n/a
# 308098          TRANSPORTATION,BUS DRIVERS,REG          NaN
# 227367                                     NaN          NaN
# 329096               Manager, Food Service IV           n/a
# 282308          FOOD SERVICE ASSISTANT                  NaN
# ...                                        ...          ...
# 209265                   Teacher-Middle School          NaN
# 333748                            PSYCHOLOGIST          NaN
# 292626           CLERICAL, BLDG.& CONSTRUCTION          NaN
# 343458                 Teacher, Super Sub D/D           n/a
# 128261             Teacher,Spec Ed Center Prg       Regular
# 186318                    Teacher, Elementary       Regular
# 210652                                     NaN          NaN
# 340354                 ELA General Assignment       Regular
# 435205                    Teacher, Elementary       Regular
# 174827                 ELA General Assignment       Regular
# 277504                    Teacher, Elementary           n/a
# 248062                                     NaN          NaN
# 70455           TEACHER, SOC STUDIES-MIDDLE             NaN
# 203453                                     NaN          NaN
# 58170                                      NaN          NaN
# 68311                     Teacher, Elementary           n/a
# 225892                    Teacher, Elementary       Regular
# 446383                                     NaN          NaN
# 155111          TRANSPORTATION, SUBSTITUTE,REG          NaN
# 278248                                     NaN          NaN
# 397424                 Secondary Spec Ed Para    Turnaround
# 375092                                     NaN          NaN
# 220181          CAFETERIA EMPLOYEE, FOOD SERV.          NaN
# 307423                                     NaN          NaN
# 46691                     Teacher, Elementary           n/a
# 109283          CURRICULUM RESOURCE TEACHER             NaN
# 102430            Teacher,Retrd Shrt Term Sub       Regular
# 413949                          School Liaison          NaN
# 433672                  Library Technician II           n/a
# 415831                 TEACHER SUBSTITUTE POOL          NaN
#
#                                     Text_4  \
# 134338                                 NaN
# 326408                 Regular Instruction
# 364634                                 NaN
# 47683                                  NaN
# 229958                                 NaN
# 417668                                 NaN
# 126378                                 NaN
# 85262                                  NaN
# 304569                                 NaN
# 84272                  Regular Instruction
# 64760                                  NaN
# 21870                                  NaN
# 169454                                 NaN
# 169914                                 NaN
# 189701                                 NaN
# 43727                                  NaN
# 5614                                   NaN
# 307038                                 NaN
# 27645                                  NaN
# 126388                 Regular Instruction
# 14962                           SIG - ARRA
# 84040                                  NaN
# 61639                                  NaN
# 266302                                 NaN
# 225768        Transportation - Bus Drivers
# 267322                                 NaN
# 308098        Transportation - Bus Drivers
# 227367                                 NaN
# 329096                                 NaN
# 282308                                 NaN
# ...                                    ...
# 209265                                 NaN
# 333748                                 NaN
# 292626                                 NaN
# 343458                                 NaN
# 128261                                 NaN
# 186318                                 NaN
# 210652                       IDEA Part B
# 340354                                 NaN
# 435205                                 NaN
# 174827                                 NaN
# 277504                                 NaN
# 248062                                 NaN
# 70455                                  NaN
# 203453                                 NaN
# 58170                      State TIF Grant
# 68311                                  NaN
# 225892                                 NaN
# 446383                                 NaN
# 155111        transportation - Second Runs
# 278248                                 NaN
# 397424                                 NaN
# 375092                 Regular Instruction
# 220181                       Undistributed
# 307423                                 NaN
# 46691                                  NaN
# 109283                                 NaN
# 102430                                 NaN
# 413949                                 NaN
# 433672                                 NaN
# 415831  Multilingual Dist Prof Development
#
#                                Sub_Object_Description  \
# 134338                                            NaN
# 326408                                            NaN
# 364634                                            NaN
# 47683                                             NaN
# 229958                                            NaN
# 417668                                            NaN
# 126378                                            NaN
# 85262                                             NaN
# 304569                                    Equipment *
# 84272                                             NaN
# 64760       Certificated Employees Salaries And Wages
# 21870                                             NaN
# 169454                                            NaN
# 169914                                            NaN
# 189701                                            NaN
# 43727                Travel Mileage/Meeting Expense *
# 5614                               Purchased Services
# 307038      Certificated Employees Salaries And Wages
# 27645                                             NaN
# 126388                                            NaN
# 14962                                             NaN
# 84040                                     Equipment *
# 61639                                             NaN
# 266302                                            NaN
# 225768  Extra Duty Pay/Overtime For Support Personnel
# 267322                                            NaN
# 308098  Extra Duty Pay/Overtime For Support Personnel
# 227367                             Purchased Services
# 329096                                            NaN
# 282308                                            NaN
# ...                                               ...
# 209265                                            NaN
# 333748      Certificated Employees Salaries And Wages
# 292626  Extra Duty Pay/Overtime For Support Personnel
# 343458                                            NaN
# 128261                                            NaN
# 186318                                            NaN
# 210652                                            NaN
# 340354                                            NaN
# 435205                                            NaN
# 174827                                            NaN
# 277504                                            NaN
# 248062         Travel And Subsistence - Employee Only
# 70455                                             NaN
# 203453                                            NaN
# 58170                                             NaN
# 68311                                             NaN
# 225892                                            NaN
# 446383                         Pupil Transportation *
# 155111  Extra Duty Pay/Overtime For Support Personnel
# 278248                                            NaN
# 397424                                            NaN
# 375092                                            NaN
# 220181        Salaries Or Wages For Support Personnel
# 307423                            Awards And Prizes *
# 46691                                             NaN
# 109283                                            NaN
# 102430                                            NaN
# 413949                                            NaN
# 433672                                            NaN
# 415831     Inservice Substitute Teachers Grant Funded
#
#                   Location_Description  \
# 134338                             NaN
# 326408                             NaN
# 364634                             NaN
# 47683                              NaN
# 229958                             NaN
# 417668                             NaN
# 126378  DISTRICT WIDE ORGANIZATION UNI
# 85262                              NaN
# 304569                             NaN
# 84272                              NaN
# 64760                              NaN
# 21870                          CHARTER
# 169454                         School
# 169914    SAFETY AND SECURITY DIVISION
# 189701                             NaN
# 43727                              NaN
# 5614                               NaN
# 307038      SR OTH CERTIFICATED PERSON
# 27645                          CHARTER
# 126388                             NaN
# 14962                              NaN
# 84040                              NaN
# 61639                              NaN
# 266302                             NaN
# 225768                   Undistributed
# 267322                             NaN
# 308098                   Undistributed
# 227367                             NaN
# 329096                             NaN
# 282308                         School
# ...                                ...
# 209265                             NaN
# 333748      PSYCHOLOGICAL SERVICES OFF
# 292626                     Unallocated
# 343458       ALL SCHOOLS-UNDISTRIBUTED
# 128261                             NaN
# 186318                             NaN
# 210652                             NaN
# 340354                             NaN
# 435205                             NaN
# 174827                             NaN
# 277504                             NaN
# 248062                         School
# 70455                          School
# 203453                         School
# 58170                              NaN
# 68311                   MATH / SCIENCE
# 225892                             NaN
# 446383                             NaN
# 155111                     Unallocated
# 278248                             NaN
# 397424                             NaN
# 375092                             NaN
# 220181                         School
# 307423                             NaN
# 46691                   MATH / SCIENCE
# 109283  STAFF DEV AND INSTR MEDIA
# 102430                             NaN
# 413949                             NaN
# 433672            ED RESOURCE SERVICES
# 415831                         School
#
#                                      Function_Description  \
# 134338                                                NaN
# 326408                                                NaN
# 364634                            UNALLOC BUDGETS/SCHOOLS
# 47683                                         NON-PROJECT
# 229958                                        NON-PROJECT
# 417668                                                NaN
# 126378                                        NON-PROJECT
# 85262                             UNALLOC BUDGETS/SCHOOLS
# 304569  State and Federal Projects Coordination Services*
# 84272                                                 NaN
# 64760                               Disadvantaged Youth *
# 21870                      BASIC (FEFP K-12)
# 169454                     BASIC (FEFP K-12)
# 169914                                  Security Services
# 189701                                        NON-PROJECT
# 43727   Instruction And Curriculum Development Services *
# 5614             Direction Of Support Services - Pupils *
# 307038                              Disadvantaged Youth *
# 27645                      GUIDANCE SERVICES
# 126388                                                NaN
# 14962                                                 NaN
# 84040   Instruction And Curriculum Development Services *
# 61639                                        CORE MATTERS
# 266302                       ELA E-TEACHING SHELTERED ENG
# 225768                                     Transportation
# 267322                                        NON-PROJECT
# 308098                                     Transportation
# 227367                         Other Community Services *
# 329096                                        NON-PROJECT
# 282308                     FOOD SERVICE
# ...                                                   ...
# 209265                                                NaN
# 333748                           Psychological Services *
# 292626            Facilities Acquisition And Construction
# 343458                            UNALLOC BUDGETS/SCHOOLS
# 128261                         SPECIAL ED. - SEVERE NEEDS
# 186318                      ELA S - TEACHING SPANISH ONLY
# 210652                                                NaN
# 340354                                     TITLE III  ELA
# 435205                        READ TO ACHIEVE ROUND THREE
# 174827                                            TITLE I
# 277504                                        NON-PROJECT
# 248062  Curriculum Development And Instructional Staff...
# 70455                      BASIC (FEFP K-12)
# 203453                     STAFF SERVICES
# 58170                                                 NaN
# 68311                      TITLE II-PART A-TEACHER QUALIT
# 225892                       ELA E-TEACHING SHELTERED ENG
# 446383  Instruction And Curriculum Development Services *
# 155111                                     Transportation
# 278248                                        INSTRUCTION
# 397424                                            NS  GOB
# 375092                                                NaN
# 220181          Food Services (Child Nutrition Fund Only)
# 307423       Other Improvements Of Instruction Services *
# 46691                      TITLE II-PART A-TEACHER QUALIT
# 109283                     INST STAFF TRAINING SVCS
# 102430                                         TITLE II,D
# 413949                                                NaN
# 433672                                        NON-PROJECT
# 415831                                        Instruction
#
#                             Facility_or_Department  \
# 134338                                         NaN
# 326408                                         NaN
# 364634                                         NaN
# 47683                                          NaN
# 229958                                         NaN
# 417668                                         NaN
# 126378                                         NaN
# 85262                                          NaN
# 304569                                         NaN
# 84272                       POSITION CONTROL POOLS
# 64760                                          NaN
# 21870                                          NaN
# 169454                                         NaN
# 169914                                         NaN
# 189701                                         NaN
# 43727                                          NaN
# 5614                                           NaN
# 307038                                         NaN
# 27645                                          NaN
# 126388                                         NaN
# 14962                                          NaN
# 84040                                          NaN
# 61639                                          NaN
# 266302                                         NaN
# 225768                   Transportation Department
# 267322                                         NaN
# 308098                   Transportation Department
# 227367                                         NaN
# 329096                                         NaN
# 282308                                         NaN
# ...                                            ...
# 209265                                         NaN
# 333748                                         NaN
# 292626  New Construction Department Administration
# 343458                                         NaN
# 128261                                         NaN
# 186318                                         NaN
# 210652                              TEACHER SUPPLY
# 340354                                         NaN
# 435205                                         NaN
# 174827                                         NaN
# 277504                                         NaN
# 248062                                  Vocational
# 70455                                          NaN
# 203453                                         NaN
# 58170                                          NaN
# 68311                                          NaN
# 225892                                         NaN
# 446383                                         NaN
# 155111                   Transportation Department
# 278248                                         NaN
# 397424                                         NaN
# 375092                                         NaN
# 220181                             Child Nutrition
# 307423                                         NaN
# 46691                                          NaN
# 109283                                         NaN
# 102430                                         NaN
# 413949                                         NaN
# 433672                                         NaN
# 415831                  Instruction And Curriculum
#
#                        Position_Extra             Program_Description  \
# 134338                  KINDERGARTEN                     KINDERGARTEN
# 326408                        TEACHER           Instruction - Regular
# 364634     PROFESSIONAL-INSTRUCTIONAL  GENERAL MIDDLE/JUNIOR HIGH SCH
# 47683      PROFESSIONAL-INSTRUCTIONAL   GENERAL HIGH SCHOOL EDUCATION
# 229958                   UNDESIGNATED               EMPLOYEE BENEFITS
# 417668         SUPPLIES AND MATERIALS         SPECIAL EDUCATION LOCAL
# 126378                   UNDESIGNATED                    UNDESIGNATED
# 85262      PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 304569                            NaN                             NaN
# 84272                         TEACHER           Instruction - Regular
# 64760                             NaN                             NaN
# 21870                             NaN                             NaN
# 169454                            NaN                             NaN
# 169914                            NaN                             NaN
# 189701                   UNDESIGNATED  CARE & UPKEEP OF BLDG SERVICES
# 43727                             NaN                             NaN
# 5614                              NaN                             NaN
# 307038                            NaN                             NaN
# 27645                             NaN                             NaN
# 126388             SUBSTITUTE TEACHER           Instruction - Regular
# 14962                 TEACHER -  DAYS           Instruction - Regular
# 84040                             NaN                             NaN
# 61639      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 266302     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 225768                     BUS DRIVER                   Undistributed
# 267322                   UNDESIGNATED               EMPLOYEE BENEFITS
# 308098                     BUS DRIVER                   Undistributed
# 227367                            NaN                             NaN
# 329096   CRAFTS, TRADES, AND SERVICES        FOOD PREPARATION/SERVING
# 282308                            NaN                             NaN
# ...                               ...                             ...
# 209265                    MS ENGLISH       MIDDLE SCHOOL PROGRAM  6-8
# 333748                            NaN                             NaN
# 292626         DIR EXEC DIR SECRETARY                   Undistributed
# 343458     PROFESSIONAL-INSTRUCTIONAL         OTHER GENERAL EDUCATION
# 128261     PROFESSIONAL-INSTRUCTIONAL      SPECIAL EDUCATION-TMD HIGH
# 186318     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 210652             SUBSTITUTE TEACHER              Instruction - SPED
# 340354               PARAPROFESSIONAL   GENERAL HIGH SCHOOL EDUCATION
# 435205     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 174827               PARAPROFESSIONAL    GENERAL ELEMENTARY EDUCATION
# 277504                   UNDESIGNATED               EMPLOYEE BENEFITS
# 248062                            NaN           Career And Technology
# 70455                             NaN                             NaN
# 203453                            NaN                             NaN
# 58170              SUBSTITUTE TEACHER   Support - Regular Instruction
# 68311      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 225892     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 446383                            NaN                             NaN
# 155111     RADIO & SUBSTITUTE DRIVERS                   Undistributed
# 278248                            NaN         PRIMARY GRADES PROGRAM
# 397424               PARAPROFESSIONAL  GENERAL MIDDLE/JUNIOR HIGH SCH
# 375092             SUBSTITUTE TEACHER           Instruction - Regular
# 220181       REG FOOD SERVICE WORKER                    Undistributed
# 307423                            NaN                             NaN
# 46691      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 109283                            NaN                             NaN
# 102430     PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 413949                 PARENT/TITLE I                            Misc
# 433672  OFFICE/ADMINISTRATIVE SUPPORT          MEDIA SUPPORT SERVICES
# 415831           CERTIFIED SUBSTITUTE           Accelerated Education
#
#                                          Fund_Description  \
# 134338                                       General Fund
# 326408                             General Purpose School
# 364634                                                NaN
# 47683                                                 NaN
# 229958                                                NaN
# 417668                                         LOCAL FUND
# 126378                                                NaN
# 85262                                                 NaN
# 304569                                     School to Work
# 84272                              General Purpose School
# 64760   Title I - Disadvantaged Children/Targeted Assi...
# 21870                      CONVERSION CHARTER SCHOOLS
# 169454                     GENERAL FUND
# 169914                                            General
# 189701                                                NaN
# 43727                                       Special Trust
# 5614                                        Special Trust
# 307038  Title I - Disadvantaged Children/Targeted Assi...
# 27645                      CONVERSION CHARTER SCHOOLS
# 126388                             General Purpose School
# 14962                             School Federal Projects
# 84040                                       Special Trust
# 61639                                                 NaN
# 266302                                                NaN
# 225768                             General Operating Fund
# 267322                                                NaN
# 308098                             General Operating Fund
# 227367  Title I - Disadvantaged Children/Targeted Assi...
# 329096                                                NaN
# 282308                     FOOD SERVICES
# ...                                                   ...
# 209265                                       General Fund
# 333748                                            General
# 292626                             General Operating Fund
# 343458                                                NaN
# 128261                                                NaN
# 186318                                                NaN
# 210652                            School Federal Projects
# 340354                                                NaN
# 435205                                                NaN
# 174827                                                NaN
# 277504                                                NaN
# 248062                             General Operating Fund
# 70455                      CONVERSION CHARTER SCHOOLS
# 203453                     EXTENDED LEARNING CENTER ELC
# 58170                             School Federal Projects
# 68311                                                 NaN
# 225892                                                NaN
# 446383                                      Special Trust
# 155111                             General Operating Fund
# 278248                                       General Fund
# 397424                                                NaN
# 375092                             General Purpose School
# 220181        National School Breakfast And Lunch Program
# 307423                         Miscellaneous State Grants
# 46691                                                 NaN
# 109283                     GENERAL FUND
# 102430                                                NaN
# 413949                                 Schoolwide Schools
# 433672                                                NaN
# 415831           "Title  Part A Improving Basic Programs"
#
#                                           Text_1
# 134338                                       NaN
# 326408                                       NaN
# 364634                       REGULAR INSTRUCTION
# 47683                        REGULAR INSTRUCTION
# 229958                         EMPLOYEE BENEFITS
# 417668                                       NaN
# 126378                              UNDESIGNATED
# 85262                        REGULAR INSTRUCTION
# 304569                ITEMAI-CITY-YTH EMP & OPP
# 84272                                        NaN
# 64760                                   TITLE I
# 21870                                        NaN
# 169454            TEACHER LEAD
# 169914                         SAFETY & SECURITY
# 189701              OPERATION AND MAINT OF PLANT
# 43727                      RESP SEXUAL BEHAVIOR
# 5614                        HOME TEAM MARKETING
# 307038                      BUILDING ALLOCATIONS
# 27645                                        NaN
# 126388                                       NaN
# 14962                 ESEA TITLE I DISADVANTAGED
# 84040                  KEY BANK NATIONAL ASSOCIA
# 61639                        INSTRUCTIONAL STAFF
# 266302                       REGULAR INSTRUCTION
# 225768             ADDL REGULAR PAY-NOT SMOOTHED
# 267322                         EMPLOYEE BENEFITS
# 308098                                  OVERTIME
# 227367                 TITLE I - PARENT INVOLVEM
# 329096                  FOOD SERVICES OPERATIONS
# 282308                                       NaN
# ...                                          ...
# 209265                                       NaN
# 333748                    PSYCHOLOGICAL SERVICES
# 292626                                  OVERTIME
# 343458                       REGULAR INSTRUCTION
# 128261                         SPECIAL EDUCATION
# 186318                       REGULAR INSTRUCTION
# 210652  INDIVIDUALS WITH DISABILITIES ACT PART B
# 340354                       REGULAR INSTRUCTION
# 435205                       REGULAR INSTRUCTION
# 174827                       REGULAR INSTRUCTION
# 277504                         EMPLOYEE BENEFITS
# 248062                                       NaN
# 70455                                        NaN
# 203453                                       NaN
# 58170                                      OTHER
# 68311                        INSTRUCTIONAL STAFF
# 225892                       REGULAR INSTRUCTION
# 446383                    ITEMS FOUNDATION-JUNE
# 155111                                  OVERTIME
# 278248                                       NaN
# 397424                       REGULAR INSTRUCTION
# 375092                                       NaN
# 220181                               REGULAR PAY
# 307423                  SCHOOL IMPROV INCENTIVES
# 46691                        INSTRUCTIONAL STAFF
# 109283            STAFF DEV AND INSTR MEDIA
# 102430                       INSTRUCTIONAL STAFF
# 413949                                       NaN
# 433672                       INSTRUCTIONAL STAFF
# 415831                            MISCELLANEOUS
#
# [320222 rows x 14 columns]
#  THE SHAPE OF NEW TEXT DATA
# --------------------
#
#
# (320222, 14)
#
#
# Now the New TEXT DATA IS:
# -----------------------------
#
#
#
#                                        Object_Description  \
# 134338
# 326408                       Personal Services - Teachers
# 364634                                  EMPLOYEE BENEFITS
# 47683                        TEACHER COVERAGE FOR TEACHER
# 229958                                    CONTRA BENEFITS
# 417668                                        EDUCATIONAL
# 126378                                  EMPLOYEE BENEFITS
# 85262                                   EMPLOYEE BENEFITS
# 304569                                        EQUIPMENT *
# 84272                        Personal Services - Teachers
# 64760                                           Regular *
# 21870                      OTHER PERSONAL SERVICES
# 169454                     SUPPLIES
# 169914                                          Regular *
# 189701                                        ELECTRICITY
# 43727               Non-Certificated Travel Reimbursement
# 5614                                   Purchased Services
# 307038                                          Regular *
# 27645                      BONUSES
# 126388  Personal Services - Substitute Teachers Certified
# 14962                        Personal Services - Teachers
# 84040                                         EQUIPMENT *
# 61639                                   EMPLOYEE BENEFITS
# 266302                                  EMPLOYEE BENEFITS
# 225768      Extra Duty Pay/Overtime For Support Personnel
# 267322                                    CONTRA BENEFITS
# 308098      Extra Duty Pay/Overtime For Support Personnel
# 227367                                 Purchased Services
# 329096                      SALARIES OF REGULAR EMPLOYEES
# 282308                     OTHER SUPPORT PERSONNEL
# ...                                                   ...
# 209265
# 333748                                          Regular *
# 292626      Extra Duty Pay/Overtime For Support Personnel
# 343458                     SALARIES OF PART TIME EMPLOYEE
# 128261                      SALARIES OF REGULAR EMPLOYEES
# 186318                      SALARIES OF REGULAR EMPLOYEES
# 210652  Personal Services - Substitute Teachers Non-Ce...
# 340354                                  EMPLOYEE BENEFITS
# 435205                       EMPLOYER PD MED CONTRIBUTION
# 174827                     SALARIES OF PART TIME EMPLOYEE
# 277504                                    CONTRA BENEFITS
# 248062             Travel And Subsistence - Employee Only
# 70455                      CLASSROOM TEACHER
# 203453                     IN-COUNTY TRAVEL
# 58170   Personal Services - Substitute Teachers Certified
# 68311                      ADDITIONAL/EXTRA DUTY PAY/STIP
# 225892                      SALARIES OF REGULAR EMPLOYEES
# 446383                Other Pupil Transportation Services
# 155111      Extra Duty Pay/Overtime For Support Personnel
# 278248                                           SUPPLIES
# 397424                     ADDITIONAL/EXTRA DUTY PAY/STIP
# 375092  Personal Services - Substitute Teachers Certified
# 220181            Salaries Or Wages For Support Personnel
# 307423                            Other Awards and Prizes
# 46691                      ADDITIONAL/EXTRA DUTY PAY/STIP
# 109283                     WORKSHOP PARTICIPANT
# 102430                     SALARIES OF PART TIME EMPLOYEE
# 413949
# 433672                                  EMPLOYEE BENEFITS
# 415831    Salaries And Wages For Substitute Professionals
#
#                                Text_2  \
# 134338
# 326408
# 364634                   TEACHER SUBS
# 47683                    TEACHER SUBS
# 229958
# 417668  SPECIAL EDUCATION INSTRUCTION
# 126378
# 85262                    TEACHER SUBS
# 304569
# 84272
# 64760
# 21870
# 169454
# 169914                       ADM/PROF
# 189701         OPERATIONS - UTILITIES
# 43727
# 5614
# 307038                        TEACHER
# 27645
# 126388
# 14962
# 84040
# 61639
# 266302
# 225768
# 267322
# 308098
# 227367
# 329096                  FOOD SERVICES
# 282308
# ...                               ...
# 209265
# 333748                     TEACHERSUP
# 292626
# 343458                   TEACHER SUBS
# 128261            SEVERE DISABILITIES
# 186318
# 210652
# 340354
# 435205
# 174827
# 277504
# 248062
# 70455
# 203453
# 58170
# 68311                    MATH/SCIENCE
# 225892
# 446383
# ...
# 70455                      BASIC (FEFP K-12)
# 203453                     STAFF SERVICES
# 58170
# 68311                      TITLE II-PART A-TEACHER QUALIT
# 225892                       ELA E-TEACHING SHELTERED ENG
# 446383  Instruction And Curriculum Development Services *
# 155111                                     Transportation
# 278248                                        INSTRUCTION
# 397424                                            NS  GOB
# 375092
# 220181          Food Services (Child Nutrition Fund Only)
# 307423       Other Improvements Of Instruction Services *
# 46691                      TITLE II-PART A-TEACHER QUALIT
# 109283                     INST STAFF TRAINING SVCS
# 102430                                         TITLE II,D
# 413949
# 433672                                        NON-PROJECT
# 415831                                        Instruction
#
#                             Facility_or_Department  \
# 134338
# 326408
# 364634
# 47683
# 229958
# 417668
# 126378
# 85262
# 304569
# 84272                       POSITION CONTROL POOLS
# 64760
# 21870
# 169454
# 169914
# 189701
# 43727
# 5614
# 307038
# 27645
# 126388
# 14962
# 84040
# 61639
# 266302
# 225768                   Transportation Department
# 267322
# 308098                   Transportation Department
# 227367
# 329096
# 282308
# ...                                            ...
# 209265
# 333748
# 292626  New Construction Department Administration
# 343458
# 128261
# 186318
# 210652                              TEACHER SUPPLY
# 340354
# 435205
# 174827
# 277504
# 248062                                  Vocational
# 70455
# 203453
# 58170
# 68311
# 225892
# 446383
# 155111                   Transportation Department
# 278248
# 397424
# 375092
# 220181                             Child Nutrition
# 307423
# 46691
# 109283
# 102430
# 413949
# 433672
# 415831                  Instruction And Curriculum
#
#                        Position_Extra             Program_Description  \
# 134338                  KINDERGARTEN                     KINDERGARTEN
# 326408                        TEACHER           Instruction - Regular
# 364634     PROFESSIONAL-INSTRUCTIONAL  GENERAL MIDDLE/JUNIOR HIGH SCH
# 47683      PROFESSIONAL-INSTRUCTIONAL   GENERAL HIGH SCHOOL EDUCATION
# 229958                   UNDESIGNATED               EMPLOYEE BENEFITS
# 417668         SUPPLIES AND MATERIALS         SPECIAL EDUCATION LOCAL
# 126378                   UNDESIGNATED                    UNDESIGNATED
# 85262      PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 304569
# 84272                         TEACHER           Instruction - Regular
# 64760
# 21870
# 169454
# 169914
# 189701                   UNDESIGNATED  CARE & UPKEEP OF BLDG SERVICES
# 43727
# 5614
# 307038
# 27645
# 126388             SUBSTITUTE TEACHER           Instruction - Regular
# 14962                 TEACHER -  DAYS           Instruction - Regular
# 84040
# 61639      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 266302     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 225768                     BUS DRIVER                   Undistributed
# 267322                   UNDESIGNATED               EMPLOYEE BENEFITS
# 308098                     BUS DRIVER                   Undistributed
# 227367
# 329096   CRAFTS, TRADES, AND SERVICES        FOOD PREPARATION/SERVING
# 282308
# ...                               ...                             ...
# 209265                    MS ENGLISH       MIDDLE SCHOOL PROGRAM  6-8
# 333748
# 292626         DIR EXEC DIR SECRETARY                   Undistributed
# 343458     PROFESSIONAL-INSTRUCTIONAL         OTHER GENERAL EDUCATION
# 128261     PROFESSIONAL-INSTRUCTIONAL      SPECIAL EDUCATION-TMD HIGH
# 186318     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 210652             SUBSTITUTE TEACHER              Instruction - SPED
# 340354               PARAPROFESSIONAL   GENERAL HIGH SCHOOL EDUCATION
# 435205     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 174827               PARAPROFESSIONAL    GENERAL ELEMENTARY EDUCATION
# 277504                   UNDESIGNATED               EMPLOYEE BENEFITS
# 248062                                          Career And Technology
# 70455
# 203453
# 58170              SUBSTITUTE TEACHER   Support - Regular Instruction
# 68311      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 225892     PROFESSIONAL-INSTRUCTIONAL    GENERAL ELEMENTARY EDUCATION
# 446383
# 155111     RADIO & SUBSTITUTE DRIVERS                   Undistributed
# 278248                                        PRIMARY GRADES PROGRAM
# 397424               PARAPROFESSIONAL  GENERAL MIDDLE/JUNIOR HIGH SCH
# 375092             SUBSTITUTE TEACHER           Instruction - Regular
# 220181       REG FOOD SERVICE WORKER                    Undistributed
# 307423
# 46691      PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 109283
# 102430     PROFESSIONAL-INSTRUCTIONAL    INSTRUCTIONAL STAFF TRAINING
# 413949                 PARENT/TITLE I                            Misc
# 433672  OFFICE/ADMINISTRATIVE SUPPORT          MEDIA SUPPORT SERVICES
# 415831           CERTIFIED SUBSTITUTE           Accelerated Education
#
#                                          Fund_Description  \
# 134338                                       General Fund
# 326408                             General Purpose School
# 364634
# 47683
# 229958
# 417668                                         LOCAL FUND
# 126378
# 85262
# 304569                                     School to Work
# 84272                              General Purpose School
# 64760   Title I - Disadvantaged Children/Targeted Assi...
# 21870                      CONVERSION CHARTER SCHOOLS
# 169454                     GENERAL FUND
# 169914                                            General
# 189701
# 43727                                       Special Trust
# 5614                                        Special Trust
# 307038  Title I - Disadvantaged Children/Targeted Assi...
# 27645                      CONVERSION CHARTER SCHOOLS
# 126388                             General Purpose School
# 14962                             School Federal Projects
# 84040                                       Special Trust
# 61639
# 266302
# 225768                             General Operating Fund
# 267322
# 308098                             General Operating Fund
# 227367  Title I - Disadvantaged Children/Targeted Assi...
# 329096
# 282308                     FOOD SERVICES
# ...                                                   ...
# 209265                                       General Fund
# 333748                                            General
# 292626                             General Operating Fund
# 343458
# 128261
# 186318
# 210652                            School Federal Projects
# 340354
# 435205
# 174827
# 277504
# 248062                             General Operating Fund
# 70455                      CONVERSION CHARTER SCHOOLS
# 203453                     EXTENDED LEARNING CENTER ELC
# 58170                             School Federal Projects
# 68311
# 225892
# 446383                                      Special Trust
# 155111                             General Operating Fund
# 278248                                       General Fund
# 397424
# 375092                             General Purpose School
# 220181        National School Breakfast And Lunch Program
# 307423                         Miscellaneous State Grants
# 46691
# 109283                     GENERAL FUND
# 102430
# 413949                                 Schoolwide Schools
# 433672
# 415831           "Title  Part A Improving Basic Programs"
#
#                                           Text_1
# 134338
# 326408
# 364634                       REGULAR INSTRUCTION
# 47683                        REGULAR INSTRUCTION
# 229958                         EMPLOYEE BENEFITS
# 417668
# 126378                              UNDESIGNATED
# 85262                        REGULAR INSTRUCTION
# 304569                ITEMAI-CITY-YTH EMP & OPP
# 84272
# 64760                                   TITLE I
# 21870
# 169454            TEACHER LEAD
# 169914                         SAFETY & SECURITY
# 189701              OPERATION AND MAINT OF PLANT
# 43727                      RESP SEXUAL BEHAVIOR
# 5614                        HOME TEAM MARKETING
# 307038                      BUILDING ALLOCATIONS
# 27645
# 126388
# 14962                 ESEA TITLE I DISADVANTAGED
# 84040                  KEY BANK NATIONAL ASSOCIA
# 61639                        INSTRUCTIONAL STAFF
# 266302                       REGULAR INSTRUCTION
# 225768             ADDL REGULAR PAY-NOT SMOOTHED
# 267322                         EMPLOYEE BENEFITS
# 308098                                  OVERTIME
# 227367                 TITLE I - PARENT INVOLVEM
# 329096                  FOOD SERVICES OPERATIONS
# 282308
# ...                                          ...
# 209265
# 333748                    PSYCHOLOGICAL SERVICES
# 292626                                  OVERTIME
# 343458                       REGULAR INSTRUCTION
# 128261                         SPECIAL EDUCATION
# 186318                       REGULAR INSTRUCTION
# 210652  INDIVIDUALS WITH DISABILITIES ACT PART B
# 340354                       REGULAR INSTRUCTION
# 435205                       REGULAR INSTRUCTION
# 174827                       REGULAR INSTRUCTION
# 277504                         EMPLOYEE BENEFITS
# 248062
# 70455
# 203453
# 58170                                      OTHER
# 68311                        INSTRUCTIONAL STAFF
# 225892                       REGULAR INSTRUCTION
# 446383                    ITEMS FOUNDATION-JUNE
# 155111                                  OVERTIME
# 278248
# 397424                       REGULAR INSTRUCTION
# 375092
# 220181                               REGULAR PAY
# 307423                  SCHOOL IMPROV INCENTIVES
# 46691                        INSTRUCTIONAL STAFF
# 109283            STAFF DEV AND INSTR MEDIA
# 102430                       INSTRUCTIONAL STAFF
# 413949
# 433672                       INSTRUCTIONAL STAFF
# 415831                            MISCELLANEOUS
#
# [320222 rows x 14 columns]

# %%
# Fit to the training data
pl.fit(X_train, y_train)

# Compute and print accuracy
accuracy = pl.score(X_test, y_test)
print("\nAccuracy on budget dataset: ", accuracy)
